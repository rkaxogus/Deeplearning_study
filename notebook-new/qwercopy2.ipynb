# %%
#클래스별로 분배 잘됨, 모델이름 model3new.pth
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
import json
import csv
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np
from torch.optim.lr_scheduler import StepLR
from torch.cuda.amp import GradScaler, autocast  # 혼합 정밀도 학습

os.environ["TORCH_COMPILE_DISABLE"] = "1"
os.environ["FUNCTORCH_COMPILE_DISABLE"] = "1"

# ✅ 하이퍼파라미터 설정
batch_size = 32
epochs = 100
learning_rate = 0.001
early_stop_threshold = 0.99  # 얼리스탑 기준 (검증 정확도 99% 이상)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ✅ 경로 설정
train_dir = 'C:/Users/user/OneDrive/Desktop/Resnet182-real/data/category_data5'
json_dir = 'C:/Users/user/OneDrive/Desktop/Resnet182-real/jsonnew'
csv_dir = 'C:/Users/user/OneDrive/Desktop/Resnet182-real/csv'
model_dir = 'C:/Users/user/OneDrive/Desktop/Resnet182-real/model'

# 필요한 디렉터리가 없으면 생성
os.makedirs(json_dir, exist_ok=True)
os.makedirs(csv_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

# ✅ 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# ✅ 데이터셋 로드
dataset = datasets.ImageFolder(root=train_dir, transform=transform)

# ✅ 데이터 분할 (7:2:1 비율)
train_data, temp_data = train_test_split(dataset.samples, test_size=0.3, stratify=dataset.targets)
val_data, test_data = train_test_split(temp_data, test_size=0.33, stratify=[item[1] for item in temp_data])

# ✅ JSON 파일로 데이터셋 저장
train_json_path = os.path.join(json_dir, "trainqwercopy2.json")
val_json_path = os.path.join(json_dir, "valqwercopy2.json")
test_json_path = os.path.join(json_dir, "testqwercopy2.json")

with open(train_json_path, "w") as f:
    json.dump(train_data, f)
with open(val_json_path, "w") as f:
    json.dump(val_data, f)
with open(test_json_path, "w") as f:
    json.dump(test_data, f)

print(f"✅ 학습 데이터 JSON 저장 완료: {train_json_path}")
print(f"✅ 검증 데이터 JSON 저장 완료: {val_json_path}")
print(f"✅ 테스트 데이터 JSON 저장 완료: {test_json_path}")

# ✅ 데이터셋을 위한 커스텀 클래스 정의
class CustomDataset(Dataset):
    def __init__(self, data, dataset, transform=None):
        self.data = data
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path, label = self.data[idx]
        image = self.dataset.loader(img_path)
        if self.transform:
            image = self.transform(image)
        return image, label

# ✅ 학습, 검증, 테스트 데이터로더 생성
train_dataset = CustomDataset(train_data, dataset, transform)
val_dataset = CustomDataset(val_data, dataset, transform)
test_dataset = CustomDataset(test_data, dataset, transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# ✅ EfficientNet-B0 모델 정의
model = efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model.classifier = nn.Sequential(
    nn.Dropout(0.2),
    nn.Linear(model.classifier[1].in_features, len(dataset.classes))
)
model = model.to(device)

# ✅ 손실 함수 및 옵티마이저 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# ✅ 학습률 스케줄러 설정
scheduler = StepLR(optimizer, step_size=10, gamma=0.7)

# ✅ 혼합 정밀도 학습 스케일러
scaler = GradScaler()

# ✅ 모델 성능을 평가하는 함수
def evaluate(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    running_loss = 0.0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    avg_loss = running_loss / len(dataloader)
    return accuracy, avg_loss

# ✅ 학습 루프 추가
best_val_acc = 0.0
best_epoch = 0
best_model_path = os.path.join(model_dir, 'model3newcopy2.pth')
epoch_log = []

print("\n📢 Training Started! Logging Every Epoch:\n")

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in tqdm(train_loader, desc=f"📢 Epoch [{epoch+1}/{epochs}] 시작"):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        with autocast():
            outputs = model(inputs)
            loss = criterion(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_acc = correct / total
    train_loss = running_loss / len(train_loader)
    val_acc, val_loss = evaluate(model, val_loader)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch + 1
        torch.save(model.state_dict(), best_model_path)
        print(f"✅ 새로운 최고 검증 정확도 {best_val_acc:.4f} (Loss: {val_loss:.4f}) 달성! 모델 저장됨 (에포크 {best_epoch})")

    epoch_log.append([epoch + 1, train_acc, train_loss, val_acc, val_loss])
    print(f"   🎯 Train Accuracy: {train_acc:.4f} | 📉 Train Loss: {train_loss:.4f} "
        f"| 🎯 Valid Accuracy: {val_acc:.4f} | 📉 Valid Loss: {val_loss:.4f}")

    if val_acc >= early_stop_threshold:
        print(f"🚨 얼리스탑! 검증 정확도가 {val_acc:.4f}로 0.99에 도달하여 학습을 종료합니다.")
        break

    scheduler.step()

# ✅ 학습 기록을 CSV 파일로 저장
with open(os.path.join(csv_dir, 'qwercopy2.csv'), 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Epoch', 'Train Accuracy', 'Train Loss', 'Val Accuracy', 'Val Loss'])
    writer.writerows(epoch_log)

# ✅ 최종 모델을 테스트 데이터로 평가
test_acc, test_loss = evaluate(model, test_loader)
print(f"🎯 Test Accuracy: {test_acc:.4f}, 📉 Test Loss: {test_loss:.4f}")
# Out:
# ✅ 학습 데이터 JSON 저장 완료: C:/Users/user/OneDrive/Desktop/Resnet182-real/jsonnew\trainqwercopy2.json
# ✅ 검증 데이터 JSON 저장 완료: C:/Users/user/OneDrive/Desktop/Resnet182-real/jsonnew\valqwercopy2.json
# ✅ 테스트 데이터 JSON 저장 완료: C:/Users/user/OneDrive/Desktop/Resnet182-real/jsonnew\testqwercopy2.json
# C:\Users\user\AppData\Local\Temp\ipykernel_11492\3089378122.py:110: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# 📢 Training Started! Logging Every Epoch:
# 📢 Epoch [1/100] 시작:   0%|          | 0/134 [00:00<?, ?it/s]C:\Users\user\AppData\Local\Temp\ipykernel_11492\3089378122.py:148: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 📢 Epoch [1/100] 시작: 100%|██████████| 134/134 [01:10<00:00,  1.89it/s]
# ✅ 새로운 최고 검증 정확도 0.8779 (Loss: 0.4095) 달성! 모델 저장됨 (에포크 1)
#    🎯 Train Accuracy: 0.7867 | 📉 Train Loss: 0.6821 | 🎯 Valid Accuracy: 0.8779 | 📉 Valid Loss: 0.4095
# 📢 Epoch [2/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
# ✅ 새로운 최고 검증 정확도 0.9024 (Loss: 0.3076) 달성! 모델 저장됨 (에포크 2)
#    🎯 Train Accuracy: 0.9059 | 📉 Train Loss: 0.2921 | 🎯 Valid Accuracy: 0.9024 | 📉 Valid Loss: 0.3076
# 📢 Epoch [3/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9355 | 📉 Train Loss: 0.2077 | 🎯 Valid Accuracy: 0.8918 | 📉 Valid Loss: 0.3563
# 📢 Epoch [4/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.39it/s]
# ✅ 새로운 최고 검증 정확도 0.9162 (Loss: 0.2940) 달성! 모델 저장됨 (에포크 4)
#    🎯 Train Accuracy: 0.9521 | 📉 Train Loss: 0.1489 | 🎯 Valid Accuracy: 0.9162 | 📉 Valid Loss: 0.2940
# 📢 Epoch [5/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
#    🎯 Train Accuracy: 0.9533 | 📉 Train Loss: 0.1309 | 🎯 Valid Accuracy: 0.9064 | 📉 Valid Loss: 0.2982
# 📢 Epoch [6/100] 시작: 100%|██████████| 134/134 [00:57<00:00,  2.34it/s]
# ✅ 새로운 최고 검증 정확도 0.9235 (Loss: 0.2803) 달성! 모델 저장됨 (에포크 6)
#    🎯 Train Accuracy: 0.9678 | 📉 Train Loss: 0.1038 | 🎯 Valid Accuracy: 0.9235 | 📉 Valid Loss: 0.2803
# 📢 Epoch [7/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
# ✅ 새로운 최고 검증 정확도 0.9325 (Loss: 0.2598) 달성! 모델 저장됨 (에포크 7)
#    🎯 Train Accuracy: 0.9605 | 📉 Train Loss: 0.1189 | 🎯 Valid Accuracy: 0.9325 | 📉 Valid Loss: 0.2598
# 📢 Epoch [8/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9703 | 📉 Train Loss: 0.0989 | 🎯 Valid Accuracy: 0.9251 | 📉 Valid Loss: 0.2821
# 📢 Epoch [9/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9827 | 📉 Train Loss: 0.0530 | 🎯 Valid Accuracy: 0.9284 | 📉 Valid Loss: 0.3373
# 📢 Epoch [10/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9776 | 📉 Train Loss: 0.0667 | 🎯 Valid Accuracy: 0.9162 | 📉 Valid Loss: 0.3654
# 📢 Epoch [11/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.41it/s]
# ✅ 새로운 최고 검증 정확도 0.9414 (Loss: 0.2243) 달성! 모델 저장됨 (에포크 11)
#    🎯 Train Accuracy: 0.9858 | 📉 Train Loss: 0.0430 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2243
# 📢 Epoch [12/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
# ✅ 새로운 최고 검증 정확도 0.9520 (Loss: 0.2118) 달성! 모델 저장됨 (에포크 12)
#    🎯 Train Accuracy: 0.9953 | 📉 Train Loss: 0.0159 | 🎯 Valid Accuracy: 0.9520 | 📉 Valid Loss: 0.2118
# 📢 Epoch [13/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9984 | 📉 Train Loss: 0.0084 | 🎯 Valid Accuracy: 0.9447 | 📉 Valid Loss: 0.2182
# 📢 Epoch [14/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 0.9965 | 📉 Train Loss: 0.0114 | 🎯 Valid Accuracy: 0.9471 | 📉 Valid Loss: 0.2050
# 📢 Epoch [15/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9965 | 📉 Train Loss: 0.0107 | 🎯 Valid Accuracy: 0.9496 | 📉 Valid Loss: 0.2053
# 📢 Epoch [16/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.46it/s]
#    🎯 Train Accuracy: 0.9958 | 📉 Train Loss: 0.0139 | 🎯 Valid Accuracy: 0.9382 | 📉 Valid Loss: 0.2457
# 📢 Epoch [17/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9939 | 📉 Train Loss: 0.0195 | 🎯 Valid Accuracy: 0.9373 | 📉 Valid Loss: 0.2663
# 📢 Epoch [18/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9855 | 📉 Train Loss: 0.0490 | 🎯 Valid Accuracy: 0.9154 | 📉 Valid Loss: 0.3586
# 📢 Epoch [19/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 0.9815 | 📉 Train Loss: 0.0587 | 🎯 Valid Accuracy: 0.9194 | 📉 Valid Loss: 0.3312
# 📢 Epoch [20/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.41it/s]
#    🎯 Train Accuracy: 0.9853 | 📉 Train Loss: 0.0538 | 🎯 Valid Accuracy: 0.9260 | 📉 Valid Loss: 0.3186
# 📢 Epoch [21/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9914 | 📉 Train Loss: 0.0295 | 🎯 Valid Accuracy: 0.9357 | 📉 Valid Loss: 0.2541
# 📢 Epoch [22/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9951 | 📉 Train Loss: 0.0148 | 🎯 Valid Accuracy: 0.9471 | 📉 Valid Loss: 0.2217
# 📢 Epoch [23/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9965 | 📉 Train Loss: 0.0102 | 🎯 Valid Accuracy: 0.9471 | 📉 Valid Loss: 0.2159
# 📢 Epoch [24/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.41it/s]
#    🎯 Train Accuracy: 0.9958 | 📉 Train Loss: 0.0122 | 🎯 Valid Accuracy: 0.9455 | 📉 Valid Loss: 0.2518
# 📢 Epoch [25/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9993 | 📉 Train Loss: 0.0043 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2397
# 📢 Epoch [26/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.40it/s]
#    🎯 Train Accuracy: 0.9991 | 📉 Train Loss: 0.0049 | 🎯 Valid Accuracy: 0.9430 | 📉 Valid Loss: 0.2451
# 📢 Epoch [27/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9988 | 📉 Train Loss: 0.0037 | 🎯 Valid Accuracy: 0.9439 | 📉 Valid Loss: 0.2413
# 📢 Epoch [28/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9977 | 📉 Train Loss: 0.0064 | 🎯 Valid Accuracy: 0.9430 | 📉 Valid Loss: 0.2576
# 📢 Epoch [29/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.42it/s]
#    🎯 Train Accuracy: 0.9965 | 📉 Train Loss: 0.0135 | 🎯 Valid Accuracy: 0.9349 | 📉 Valid Loss: 0.3076
# 📢 Epoch [30/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.41it/s]
#    🎯 Train Accuracy: 0.9977 | 📉 Train Loss: 0.0096 | 🎯 Valid Accuracy: 0.9308 | 📉 Valid Loss: 0.3482
# 📢 Epoch [31/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9972 | 📉 Train Loss: 0.0073 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2865
# 📢 Epoch [32/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.42it/s]
#    🎯 Train Accuracy: 0.9981 | 📉 Train Loss: 0.0056 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.3035
# 📢 Epoch [33/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
#    🎯 Train Accuracy: 0.9991 | 📉 Train Loss: 0.0029 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2970
# 📢 Epoch [34/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.41it/s]
#    🎯 Train Accuracy: 0.9977 | 📉 Train Loss: 0.0076 | 🎯 Valid Accuracy: 0.9398 | 📉 Valid Loss: 0.2922
# 📢 Epoch [35/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.38it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0017 | 🎯 Valid Accuracy: 0.9496 | 📉 Valid Loss: 0.2643
# 📢 Epoch [36/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 0.9986 | 📉 Train Loss: 0.0036 | 🎯 Valid Accuracy: 0.9390 | 📉 Valid Loss: 0.2893
# 📢 Epoch [37/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 0.9988 | 📉 Train Loss: 0.0049 | 🎯 Valid Accuracy: 0.9479 | 📉 Valid Loss: 0.2798
# 📢 Epoch [38/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.45it/s]
#    🎯 Train Accuracy: 0.9993 | 📉 Train Loss: 0.0036 | 🎯 Valid Accuracy: 0.9398 | 📉 Valid Loss: 0.3016
# 📢 Epoch [39/100] 시작: 100%|██████████| 134/134 [00:58<00:00,  2.31it/s]
#    🎯 Train Accuracy: 0.9960 | 📉 Train Loss: 0.0161 | 🎯 Valid Accuracy: 0.9251 | 📉 Valid Loss: 0.3477
# 📢 Epoch [40/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.42it/s]
#    🎯 Train Accuracy: 0.9965 | 📉 Train Loss: 0.0144 | 🎯 Valid Accuracy: 0.9406 | 📉 Valid Loss: 0.3336
# 📢 Epoch [41/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.43it/s]
#    🎯 Train Accuracy: 0.9984 | 📉 Train Loss: 0.0038 | 🎯 Valid Accuracy: 0.9349 | 📉 Valid Loss: 0.3108
# 📢 Epoch [42/100] 시작: 100%|██████████| 134/134 [00:58<00:00,  2.29it/s]
#    🎯 Train Accuracy: 0.9995 | 📉 Train Loss: 0.0029 | 🎯 Valid Accuracy: 0.9463 | 📉 Valid Loss: 0.2830
# 📢 Epoch [43/100] 시작: 100%|██████████| 134/134 [01:00<00:00,  2.20it/s]
#    🎯 Train Accuracy: 0.9991 | 📉 Train Loss: 0.0031 | 🎯 Valid Accuracy: 0.9317 | 📉 Valid Loss: 0.3065
# 📢 Epoch [44/100] 시작: 100%|██████████| 134/134 [01:03<00:00,  2.11it/s]
#    🎯 Train Accuracy: 0.9991 | 📉 Train Loss: 0.0036 | 🎯 Valid Accuracy: 0.9406 | 📉 Valid Loss: 0.2942
# 📢 Epoch [45/100] 시작: 100%|██████████| 134/134 [00:57<00:00,  2.31it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0013 | 🎯 Valid Accuracy: 0.9430 | 📉 Valid Loss: 0.2812
# 📢 Epoch [46/100] 시작: 100%|██████████| 134/134 [00:59<00:00,  2.26it/s]
#    🎯 Train Accuracy: 0.9991 | 📉 Train Loss: 0.0033 | 🎯 Valid Accuracy: 0.9382 | 📉 Valid Loss: 0.3128
# 📢 Epoch [47/100] 시작: 100%|██████████| 134/134 [01:04<00:00,  2.09it/s]
#    🎯 Train Accuracy: 0.9988 | 📉 Train Loss: 0.0046 | 🎯 Valid Accuracy: 0.9422 | 📉 Valid Loss: 0.3116
# 📢 Epoch [48/100] 시작: 100%|██████████| 134/134 [01:00<00:00,  2.21it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0016 | 🎯 Valid Accuracy: 0.9455 | 📉 Valid Loss: 0.2886
# 📢 Epoch [49/100] 시작: 100%|██████████| 134/134 [00:59<00:00,  2.27it/s]
#    🎯 Train Accuracy: 0.9986 | 📉 Train Loss: 0.0032 | 🎯 Valid Accuracy: 0.9390 | 📉 Valid Loss: 0.2786
# 📢 Epoch [50/100] 시작: 100%|██████████| 134/134 [00:58<00:00,  2.30it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0009 | 🎯 Valid Accuracy: 0.9365 | 📉 Valid Loss: 0.2838
# 📢 Epoch [51/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.38it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0019 | 🎯 Valid Accuracy: 0.9487 | 📉 Valid Loss: 0.2599
# 📢 Epoch [52/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0008 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2634
# 📢 Epoch [53/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0003 | 🎯 Valid Accuracy: 0.9439 | 📉 Valid Loss: 0.2607
# 📢 Epoch [54/100] 시작: 100%|██████████| 134/134 [01:00<00:00,  2.22it/s]
#    🎯 Train Accuracy: 0.9995 | 📉 Train Loss: 0.0019 | 🎯 Valid Accuracy: 0.9414 | 📉 Valid Loss: 0.2698
# 📢 Epoch [55/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.39it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0014 | 🎯 Valid Accuracy: 0.9406 | 📉 Valid Loss: 0.2696
# 📢 Epoch [56/100] 시작: 100%|██████████| 134/134 [00:57<00:00,  2.33it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0003 | 🎯 Valid Accuracy: 0.9422 | 📉 Valid Loss: 0.2750
# 📢 Epoch [57/100] 시작: 100%|██████████| 134/134 [00:55<00:00,  2.42it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0004 | 🎯 Valid Accuracy: 0.9439 | 📉 Valid Loss: 0.2741
# 📢 Epoch [58/100] 시작: 100%|██████████| 134/134 [00:58<00:00,  2.30it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0008 | 🎯 Valid Accuracy: 0.9422 | 📉 Valid Loss: 0.2701
# 📢 Epoch [59/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.37it/s]
#    🎯 Train Accuracy: 0.9995 | 📉 Train Loss: 0.0016 | 🎯 Valid Accuracy: 0.9430 | 📉 Valid Loss: 0.2730
# 📢 Epoch [60/100] 시작: 100%|██████████| 134/134 [00:58<00:00,  2.30it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0002 | 🎯 Valid Accuracy: 0.9406 | 📉 Valid Loss: 0.2672
# 📢 Epoch [61/100] 시작: 100%|██████████| 134/134 [00:56<00:00,  2.38it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0008 | 🎯 Valid Accuracy: 0.9390 | 📉 Valid Loss: 0.2704
# 📢 Epoch [62/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.45it/s]
#    🎯 Train Accuracy: 1.0000 | 📉 Train Loss: 0.0002 | 🎯 Valid Accuracy: 0.9439 | 📉 Valid Loss: 0.2666
# 📢 Epoch [63/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.44it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0004 | 🎯 Valid Accuracy: 0.9471 | 📉 Valid Loss: 0.2551
# 📢 Epoch [64/100] 시작: 100%|██████████| 134/134 [00:54<00:00,  2.46it/s]
#    🎯 Train Accuracy: 0.9998 | 📉 Train Loss: 0.0005 | 🎯 Valid Accuracy: 0.9406 | 📉 Valid Loss: 0.2581
# 📢 Epoch [65/100] 시작:  84%|████████▍ | 113/134 [00:52<00:09,  2.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 145
#     142 correct = 0
#     143 total = 0
# --> 145 for inputs, labels in tqdm(train_loader, desc=f"📢 Epoch [{epoch+1}/{epochs}] 시작"):
#     146     inputs, labels = inputs.to(device), labels.to(device)
#     147     optimizer.zero_grad()
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[3], line 82, in CustomDataset.__getitem__(self, idx)
#      80 image = self.dataset.loader(img_path)
#      81 if self.transform:
# ---> 82     image = self.transform(image)
#      83 return image, label
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torchvision\transforms\transforms.py:354, in Resize.forward(self, img)
#     346 def forward(self, img):
#     347     """
#     348     Args:
#     349         img (PIL Image or Tensor): Image to be scaled.
#    (...)
#     352         PIL Image or Tensor: Rescaled image.
#     353     """
# --> 354     return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torchvision\transforms\functional.py:477, in resize(img, size, interpolation, max_size, antialias)
#     475         warnings.warn("Anti-alias option is always applied for PIL Image input. Argument antialias is ignored.")
#     476     pil_interpolation = pil_modes_mapping[interpolation]
# --> 477     return F_pil.resize(img, size=output_size, interpolation=pil_interpolation)
#     479 return F_t.resize(img, size=output_size, interpolation=interpolation.value, antialias=antialias)
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\torchvision\transforms\_functional_pil.py:250, in resize(img, size, interpolation)
#     247 if not (isinstance(size, list) and len(size) == 2):
#     248     raise TypeError(f"Got inappropriate size arg: {size}")
# --> 250 return img.resize(tuple(size[::-1]), interpolation)
#
# File c:\Users\user\anaconda3\envs\classification\lib\site-packages\PIL\Image.py:2365, in Image.resize(self, size, resample, box, reducing_gap)
#    2353         self = (
#    2354             self.reduce(factor, box=reduce_box)
#    2355             if callable(self.reduce)
#    2356             else Image.reduce(self, factor, box=reduce_box)
#    2357         )
#    2358         box = (
#    2359             (box[0] - reduce_box[0]) / factor_x,
#    2360             (box[1] - reduce_box[1]) / factor_y,
#    2361             (box[2] - reduce_box[0]) / factor_x,
#    2362             (box[3] - reduce_box[1]) / factor_y,
#    2363         )
# -> 2365 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
import os
import json
import csv
import torch
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

# ---------------------------------------------
# 1. 경로 및 기본 설정
# ---------------------------------------------
json_dir   = r"C:\Users\user\OneDrive\Desktop\Resnet182-real\jsonnew"
csv_dir    = r"C:\Users\user\OneDrive\Desktop\Resnet182-real\csv"
model_path = r"C:\Users\user\OneDrive\Desktop\Resnet182-real\model\model3newcopy2.pth"
data_dir   = r"C:\Users\user\OneDrive\Desktop\Resnet182-real\data\category_data5"

batch_size = 32
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 이미지 전처리 (학습 시와 동일하게)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# ImageFolder를 사용하여 데이터셋(클래스 정보, 로더) 구성
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# ---------------------------------------------
# 2. JSON 파일 로드 (학습, 검증, 테스트 데이터)
# ---------------------------------------------
train_json_path = os.path.join(json_dir, "trainqwercopy2.json")
val_json_path   = os.path.join(json_dir, "valqwercopy2.json")
test_json_path  = os.path.join(json_dir, "testqwercopy2.json")

with open(train_json_path, "r", encoding="utf-8") as f:
    train_data_json = json.load(f)
with open(val_json_path, "r", encoding="utf-8") as f:
    val_data_json = json.load(f)
with open(test_json_path, "r", encoding="utf-8") as f:
    test_data_json = json.load(f)

# ---------------------------------------------
# 3. 평가용 Dataset 클래스 정의  
#    (JSON에 저장된 [이미지 경로, label] 리스트 사용)
# ---------------------------------------------
class CustomEvalDataset(Dataset):
    def __init__(self, data, dataset, transform=None):
        """
        data: JSON 파일에 저장된 [이미지 경로, label] 리스트
        dataset: ImageFolder 객체 (이미지 로더와 classes 사용)
        transform: 이미지 전처리
        """
        self.data = data
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path, label = self.data[idx]
        image = self.dataset.loader(img_path)
        if self.transform:
            image = self.transform(image)
        return image, label, img_path

# ---------------------------------------------
# 4. 평가용 DataLoader 생성 (Train, Validation, Test)
# ---------------------------------------------
train_eval_dataset = CustomEvalDataset(train_data_json, dataset, transform)
val_eval_dataset   = CustomEvalDataset(val_data_json, dataset, transform)
test_eval_dataset  = CustomEvalDataset(test_data_json, dataset, transform)

train_eval_loader = DataLoader(train_eval_dataset, batch_size=batch_size, shuffle=False)
val_eval_loader   = DataLoader(val_eval_dataset, batch_size=batch_size, shuffle=False)
test_eval_loader  = DataLoader(test_eval_dataset, batch_size=batch_size, shuffle=False)

# ---------------------------------------------
# 5. 모델 정의 및 가중치 로드
# ---------------------------------------------
model = efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model.classifier = torch.nn.Sequential(
    torch.nn.Dropout(0.2),
    torch.nn.Linear(model.classifier[1].in_features, len(dataset.classes))
)
model = model.to(device)
model.load_state_dict(torch.load(model_path))
model.eval()

# ---------------------------------------------
# 6. 평가 함수 정의
#    - 각 이미지별 결과: [이미지 경로, 정답 label, 예측 label, 정답 여부]
#    - 전체 이미지 수, 맞춘 개수, 틀린 개수, 정확도 계산
# ---------------------------------------------
def detailed_evaluate(model, dataloader):
    model.eval()
    details = []
    correct_count = 0
    total_count = 0
    with torch.no_grad():
        for images, labels, paths in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            for i in range(len(labels)):
                total_count += 1
                is_correct = (preds[i] == labels[i]).item()
                if is_correct:
                    correct_count += 1
                details.append([paths[i], labels[i].item(), preds[i].item(), bool(is_correct)])
    wrong_count = total_count - correct_count
    accuracy = correct_count / total_count if total_count > 0 else 0
    return total_count, correct_count, wrong_count, accuracy, details

# ---------------------------------------------
# 7. 평가 진행 및 콘솔 출력
# ---------------------------------------------
eval_loaders = {
    "Train": train_eval_loader,
    "Validation": val_eval_loader,
    "Test": test_eval_loader
}

# CSV 저장 및 콘솔 출력용 리스트
console_lines = []
# 최종 요약 저장용 리스트
final_summary = []

for ds_name, loader in eval_loaders.items():
    total, correct, wrong, acc, details = detailed_evaluate(model, loader)
    summary_line = f"👉 {ds_name} 데이터셋: 총 {total}개 이미지 중 {correct}개 정답, {wrong}개 오답 (정확도: {acc:.4f})"
    print(summary_line)
    console_lines.append(summary_line)
    final_summary.append(summary_line)
    for idx, (img_path, true_label, pred_label, is_correct) in enumerate(details):
        true_class = dataset.classes[true_label]
        pred_class = dataset.classes[pred_label]
        result_line = f"[{ds_name} {idx+1}] 예측: '{pred_class}'(🔮) / 실제: '{true_class}'(🎯) -> {'정답 🟢' if is_correct else '오답 🔴'}"
        print(result_line)
        console_lines.append(result_line)

# ---------------------------------------------
# 8. 평가 결과 CSV 파일로 저장 (콘솔 출력 내용 + 최종 요약)
# ---------------------------------------------
csv_filename = "최종모델성능평가.csv"
csv_path = os.path.join(csv_dir, csv_filename)

# 최종 요약도 console_lines 리스트에 추가
console_lines.append("")  # 빈 줄 추가
console_lines.extend(final_summary)

with open(csv_path, "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    for line in console_lines:
        writer.writerow([line])

print(f"\n✅ 평가 결과가 CSV 파일에 저장되었습니다: {csv_path}")

# ---------------------------------------------
# 9. 최종 평가 요약 별도 출력
# ---------------------------------------------
print("\n===== 최종 평가 요약 =====")
for summary in final_summary:
    print(summary)
# Out:
# 👉 Train 데이터셋: 총 4281개 이미지 중 4280개 정답, 1개 오답 (정확도: 0.9998)
# [Train 1] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 2] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 3] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 4] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 5] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 6] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 7] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 8] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 9] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 10] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 11] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 12] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 13] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 14] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 15] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 16] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 17] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 18] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 19] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 20] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 21] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 22] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 23] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 24] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 25] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 26] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 27] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 28] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 29] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 30] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 31] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 32] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 33] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 34] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 35] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 36] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 37] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 38] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 39] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 40] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 41] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 42] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 43] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 44] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 45] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 46] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 47] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 48] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 49] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 50] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 51] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 52] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 53] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 54] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 55] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 56] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 57] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 58] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 59] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 60] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 61] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 62] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 63] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 64] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 65] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 66] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 67] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 68] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 69] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 70] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 71] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 72] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 73] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 74] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 75] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 76] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 77] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 78] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 79] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 80] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 81] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 82] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 83] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 84] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 85] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 86] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 87] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 88] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 89] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 90] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 91] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 92] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 93] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 94] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 95] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 96] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 97] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 98] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 99] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 100] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 101] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 102] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 103] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 104] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 105] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 106] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 107] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 108] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 109] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 110] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 111] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 112] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 113] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 114] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 115] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 116] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 117] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 118] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 119] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 120] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 121] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 122] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 123] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 124] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 125] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 126] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 127] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 128] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 129] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 130] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 131] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 132] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 133] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 134] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 135] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 136] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 137] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 138] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 139] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 140] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 141] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 142] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 143] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 144] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 145] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 146] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 147] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 148] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 149] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 150] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 151] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 152] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 153] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 154] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 155] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 156] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 157] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 158] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 159] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 160] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 161] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 162] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 163] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 164] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 165] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 166] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 167] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 168] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 169] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 170] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 171] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 172] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 173] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 174] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 175] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 176] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 177] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 178] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 179] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 180] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 181] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 182] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 183] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 184] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 185] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 186] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 187] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 188] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 189] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 190] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 191] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 192] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 193] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 194] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 195] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 196] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 197] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 198] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 199] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 200] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 201] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 202] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 203] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 204] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 205] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 206] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 207] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 208] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 209] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 210] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 211] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 212] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 213] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 214] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 215] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 216] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 217] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 218] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 219] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 220] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 221] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 222] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 223] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 224] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 225] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 226] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 227] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 228] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 229] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 230] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 231] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 232] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 233] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 234] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 235] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 236] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 237] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 238] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 239] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 240] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 241] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 242] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 243] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 244] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 245] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 246] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 247] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 248] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 249] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 250] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 251] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 252] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 253] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 254] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 255] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 256] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 257] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 258] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 259] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 260] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 261] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 262] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 263] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 264] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 265] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 266] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 267] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 268] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 269] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 270] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 271] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 272] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 273] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 274] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 275] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 276] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 277] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 278] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 279] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 280] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 281] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 282] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 283] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 284] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 285] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 286] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 287] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 288] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 289] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 290] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 291] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 292] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 293] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 294] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 295] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 296] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 297] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 298] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 299] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 300] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 301] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 302] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 303] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 304] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 305] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 306] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 307] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 308] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 309] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 310] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 311] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 312] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 313] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 314] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 315] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 316] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 317] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 318] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 319] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 320] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 321] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 322] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 323] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 324] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 325] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 326] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 327] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 328] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 329] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 330] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 331] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 332] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 333] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 334] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 335] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 336] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 337] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 338] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 339] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 340] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 341] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 342] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 343] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 344] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 345] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 346] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 347] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 348] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 349] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 350] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 351] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 352] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 353] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 354] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 355] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 356] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 357] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 358] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 359] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 360] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 361] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 362] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 363] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 364] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 365] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 366] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 367] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 368] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 369] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 370] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 371] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 372] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 373] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 374] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 375] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 376] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 377] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 378] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 379] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 380] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 381] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 382] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 383] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 384] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 385] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 386] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 387] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 388] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 389] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 390] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 391] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 392] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 393] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 394] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 395] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 396] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 397] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 398] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 399] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 400] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 401] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 402] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 403] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 404] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 405] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 406] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 407] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 408] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 409] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 410] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 411] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 412] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 413] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 414] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 415] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 416] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 417] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 418] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 419] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 420] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 421] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 422] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 423] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 424] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 425] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 426] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 427] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 428] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 429] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 430] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 431] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 432] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 433] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 434] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 435] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 436] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 437] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 438] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 439] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 440] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 441] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 442] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 443] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 444] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 445] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 446] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 447] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 448] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 449] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 450] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 451] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 452] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 453] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 454] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 455] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 456] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 457] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 458] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 459] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 460] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 461] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 462] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 463] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 464] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 465] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 466] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 467] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 468] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 469] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 470] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 471] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 472] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 473] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 474] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 475] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 476] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 477] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 478] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 479] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 480] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 481] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 482] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 483] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 484] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 485] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 486] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 487] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 488] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 489] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 490] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 491] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 492] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 493] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 494] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 495] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 496] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 497] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 498] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 499] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 500] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 501] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 502] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 503] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 504] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 505] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 506] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 507] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 508] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 509] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 510] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 511] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 512] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 513] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 514] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 515] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 516] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 517] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 518] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 519] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 520] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 521] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 522] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 523] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 524] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 525] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 526] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 527] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 528] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 529] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 530] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 531] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 532] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 533] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 534] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 535] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 536] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 537] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 538] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 539] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 540] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 541] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 542] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 543] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 544] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 545] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 546] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 547] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 548] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 549] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 550] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 551] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 552] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 553] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 554] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 555] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 556] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 557] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 558] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 559] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 560] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 561] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 562] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 563] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 564] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 565] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 566] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 567] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 568] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 569] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 570] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 571] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 572] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 573] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 574] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 575] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 576] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 577] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 578] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 579] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 580] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 581] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 582] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 583] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 584] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 585] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 586] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 587] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 588] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 589] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 590] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 591] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 592] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 593] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 594] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 595] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 596] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 597] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 598] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 599] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 600] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 601] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 602] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 603] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 604] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 605] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 606] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 607] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 608] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 609] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 610] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 611] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 612] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 613] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 614] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 615] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 616] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 617] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 618] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 619] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 620] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 621] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 622] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 623] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 624] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 625] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 626] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 627] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 628] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 629] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 630] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 631] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 632] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 633] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 634] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 635] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 636] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 637] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 638] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 639] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 640] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 641] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 642] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 643] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 644] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 645] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 646] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 647] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 648] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 649] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 650] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 651] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 652] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 653] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 654] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 655] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 656] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 657] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 658] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 659] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 660] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 661] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 662] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 663] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 664] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 665] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 666] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 667] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 668] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 669] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 670] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 671] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 672] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 673] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 674] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 675] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 676] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 677] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 678] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 679] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 680] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 681] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 682] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 683] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 684] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 685] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 686] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 687] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 688] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 689] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 690] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 691] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 692] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 693] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 694] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 695] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 696] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 697] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 698] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 699] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 700] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 701] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 702] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 703] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 704] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 705] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 706] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 707] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 708] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 709] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 710] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 711] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 712] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 713] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 714] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 715] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 716] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 717] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 718] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 719] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 720] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 721] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 722] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 723] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 724] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 725] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 726] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 727] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 728] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 729] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 730] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 731] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 732] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 733] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 734] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 735] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 736] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 737] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 738] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 739] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 740] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 741] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 742] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 743] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 744] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 745] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 746] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 747] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 748] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 749] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 750] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 751] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 752] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 753] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 754] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 755] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 756] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 757] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 758] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 759] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 760] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 761] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 762] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 763] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 764] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 765] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 766] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 767] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 768] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 769] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 770] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 771] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 772] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 773] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 774] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 775] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 776] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 777] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 778] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 779] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 780] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 781] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 782] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 783] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 784] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 785] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 786] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 787] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 788] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 789] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 790] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 791] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 792] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 793] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 794] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 795] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 796] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 797] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 798] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 799] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 800] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 801] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 802] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 803] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 804] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 805] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 806] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 807] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 808] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 809] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 810] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 811] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 812] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 813] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 814] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 815] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 816] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 817] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 818] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 819] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 820] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 821] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 822] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 823] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 824] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 825] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 826] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 827] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 828] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 829] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 830] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 831] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 832] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 833] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 834] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 835] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 836] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 837] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 838] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 839] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 840] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 841] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 842] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 843] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 844] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 845] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 846] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 847] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 848] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 849] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 850] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 851] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 852] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 853] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 854] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 855] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 856] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 857] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 858] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 859] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 860] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 861] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 862] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 863] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 864] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 865] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Train 866] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 867] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 868] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 869] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 870] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 871] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 872] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 873] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 874] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 875] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 876] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Train 877] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 878] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 879] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 880] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 881] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 882] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 883] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Train 884] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 885] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 886] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 887] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Train 888] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Train 889] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Train 890] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Train 891] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Train 892] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Train 893] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Train 894] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# ...
# [Test 310] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 311] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 312] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 313] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 314] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 315] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 316] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 317] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 318] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 319] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 320] 예측: '매트·침낭'(🔮) / 실제: '공구·액세서리'(🎯) -> 오답 🔴
# [Test 321] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 322] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 323] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 324] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 325] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 326] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 327] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 328] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 329] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 330] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 331] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 332] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 333] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 334] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 335] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 336] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 337] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 338] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 339] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 340] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 341] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 342] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 343] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 344] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 345] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 346] 예측: '화로대·버너'(🔮) / 실제: '테이블·체어'(🎯) -> 오답 🔴
# [Test 347] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 348] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 349] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 350] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 351] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 352] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 353] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 354] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 355] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 356] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 357] 예측: '식기·주방'(🔮) / 실제: '화로대·버너'(🎯) -> 오답 🔴
# [Test 358] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 359] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 360] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 361] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 362] 예측: '냉·난방용품'(🔮) / 실제: '랜턴'(🎯) -> 오답 🔴
# [Test 363] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 364] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 365] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 366] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 367] 예측: '가방·박스·웨건'(🔮) / 실제: '매트·침낭'(🎯) -> 오답 🔴
# [Test 368] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 369] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 370] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 371] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 372] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 373] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 374] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 375] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 376] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 377] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 378] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 379] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 380] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 381] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 382] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 383] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 384] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 385] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 386] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 387] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 388] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 389] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 390] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 391] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 392] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 393] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 394] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 395] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 396] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 397] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 398] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 399] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 400] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 401] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 402] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 403] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 404] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 405] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 406] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 407] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 408] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 409] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 410] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 411] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 412] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 413] 예측: '식기·주방'(🔮) / 실제: '전기·전자기기'(🎯) -> 오답 🔴
# [Test 414] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 415] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 416] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 417] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 418] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 419] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 420] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 421] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 422] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 423] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 424] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 425] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 426] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 427] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 428] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 429] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 430] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 431] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 432] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 433] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 434] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 435] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 436] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 437] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 438] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 439] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 440] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 441] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 442] 예측: '식기·주방'(🔮) / 실제: '랜턴'(🎯) -> 오답 🔴
# [Test 443] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 444] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 445] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 446] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 447] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 448] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 449] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 450] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 451] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 452] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 453] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 454] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 455] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 456] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 457] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 458] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 459] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 460] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 461] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 462] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 463] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 464] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 465] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 466] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 467] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 468] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 469] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 470] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 471] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 472] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 473] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 474] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 475] 예측: '식기·주방'(🔮) / 실제: '화로대·버너'(🎯) -> 오답 🔴
# [Test 476] 예측: '식기·주방'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 오답 🔴
# [Test 477] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 478] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 479] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 480] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 481] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 482] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 483] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 484] 예측: '가방·박스·웨건'(🔮) / 실제: '매트·침낭'(🎯) -> 오답 🔴
# [Test 485] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 486] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 487] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 488] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 489] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 490] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 491] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 492] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 493] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 494] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 495] 예측: '화로대·버너'(🔮) / 실제: '테이블·체어'(🎯) -> 오답 🔴
# [Test 496] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 497] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 498] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 499] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 500] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 501] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 502] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 503] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 504] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 505] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 506] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 507] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 508] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 509] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 510] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 511] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 512] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 513] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 514] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 515] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 516] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 517] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 518] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 519] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 520] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 521] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 522] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 523] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 524] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 525] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 526] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 527] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 528] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 529] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 530] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 531] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 532] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 533] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 534] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 535] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 536] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 537] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 538] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 539] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 540] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 541] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 542] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 543] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 544] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 545] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 546] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 547] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 548] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 549] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 550] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 551] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 552] 예측: '테이블·체어'(🔮) / 실제: '테이블·체어'(🎯) -> 정답 🟢
# [Test 553] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 554] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 555] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 556] 예측: '냉·난방용품'(🔮) / 실제: '화로대·버너'(🎯) -> 오답 🔴
# [Test 557] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 558] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 559] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 560] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 561] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 562] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 563] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 564] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 565] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 566] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 567] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 568] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 569] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 570] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 571] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 572] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 573] 예측: '전기·전자기기'(🔮) / 실제: '식기·주방'(🎯) -> 오답 🔴
# [Test 574] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 575] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 576] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 577] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 578] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 579] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 580] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 581] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 582] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 583] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 584] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 585] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 586] 예측: '텐트·타프'(🔮) / 실제: '텐트·타프'(🎯) -> 정답 🟢
# [Test 587] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 588] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 589] 예측: '가방·박스·웨건'(🔮) / 실제: '가방·박스·웨건'(🎯) -> 정답 🟢
# [Test 590] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 591] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 592] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 593] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 594] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 595] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 596] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 597] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 598] 예측: '전기·전자기기'(🔮) / 실제: '전기·전자기기'(🎯) -> 정답 🟢
# [Test 599] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 600] 예측: '식기·주방'(🔮) / 실제: '식기·주방'(🎯) -> 정답 🟢
# [Test 601] 예측: '매트·침낭'(🔮) / 실제: '매트·침낭'(🎯) -> 정답 🟢
# [Test 602] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
# [Test 603] 예측: '냉·난방용품'(🔮) / 실제: '냉·난방용품'(🎯) -> 정답 🟢
# [Test 604] 예측: '랜턴'(🔮) / 실제: '랜턴'(🎯) -> 정답 🟢
# [Test 605] 예측: '공구·액세서리'(🔮) / 실제: '공구·액세서리'(🎯) -> 정답 🟢
# [Test 606] 예측: '화로대·버너'(🔮) / 실제: '화로대·버너'(🎯) -> 정답 🟢
#
# ✅ 평가 결과가 CSV 파일에 저장되었습니다: C:\Users\user\OneDrive\Desktop\Resnet182-real\csv\최종모델성능평가.csv
#
# ===== 최종 평가 요약 =====
# 👉 Train 데이터셋: 총 4281개 이미지 중 4280개 정답, 1개 오답 (정확도: 0.9998)
# 👉 Validation 데이터셋: 총 1229개 이미지 중 1170개 정답, 59개 오답 (정확도: 0.9520)
# 👉 Test 데이터셋: 총 606개 이미지 중 574개 정답, 32개 오답 (정확도: 0.9472)
