# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torchvision.models import EfficientNet_B0_Weights
import pandas as pd

# ✅ GPU 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ 사용 중인 GPU:", torch.cuda.get_device_name(0))
else:
    print("❌ GPU를 사용할 수 없습니다. CPU에서 실행됩니다.")

# ✅ 경로 설정
data_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/data/category_data"
model_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/model"
csv_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/csv"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(csv_dir, exist_ok=True)

# ✅ 하이퍼파라미터 설정
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
EPOCHS = 500
LEARNING_RATE = 0.001

# ✅ 데이터 전처리
transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# ✅ 데이터셋 로드
dataset = datasets.ImageFolder(data_dir, transform=transform)

# ✅ 상위 클래스와 하위 클래스 매핑
category_mapping = {
    "가방.박스.웨건": ["가방.베낭", "박스", "웨건.카트"],
    "공구.액세서리": ["가랜드", "해머"],
    "냉.난방용품": ["난로.히터", "선풍기.써큘레이터", "에어컨", "전기매트.요.방석"],
    "랜턴": [],
    "매트.침낭": ["발포매트", "에어매트", "자충매트", "침낭", "침대", "카페트.러그"],
    "식기.주방": ["물통.워터저그", "세척.건조도구", "식기류", "아이스박스.쿨러", "조리도구"],
    "전기.전자기기": ["TV.모니터.빔프로젝터", "릴선.멀티탭", "스피커", "전동펌프", "파워뱅크.보조배터리"],
    "테이블.체어": ["체어", "테이블"],
    "텐트.타프": ["타프", "텐트"],
    "화로대.버너": ["그릴.그리들", "버너.토치", "화로대"]
}

# ✅ 하위 클래스를 예측하고 상위 클래스를 매핑하기 위한 함수
def map_to_top_class(sub_class, category_mapping):
    for top_class, sub_classes in category_mapping.items():
        if sub_class in sub_classes:
            return top_class
    return None  # 상위 클래스가 없다면 None 반환

# ✅ 상위 클래스 목록
top_classes = list(category_mapping.keys())
num_top_classes = len(top_classes)

# ✅ 데이터셋 분할 (10% 테스트, 나머지 90% 학습/검증)
test_size = int(0.1 * len(dataset))
train_val_size = len(dataset) - test_size
dataset_train_val, dataset_test = random_split(dataset, [train_val_size, test_size])

# ✅ 학습 및 검증 데이터 분할 (80% 학습, 20% 검증)
train_size = int(0.8 * len(dataset_train_val))
valid_size = len(dataset_train_val) - train_size
train_dataset, valid_dataset = random_split(dataset_train_val, [train_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=True)

# ✅ 모델 정의
model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model.classifier[1] = nn.Linear(model.classifier[1].in_features, len(dataset.classes))  # 하위 클래스 예측
model.to(device)

# ✅ 손실 함수 및 옵티마이저
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# ✅ 학습 루프
best_valid_accuracy = 0.0
best_epoch_info = None  # 최적 에포크 정보 저장
csv_path = os.path.join(csv_dir, "category_classification_results.csv")
train_losses, valid_losses, train_accuracies, valid_accuracies = [], [], [], []

for epoch in range(EPOCHS):
    print(f"\n📢 Epoch [{epoch+1}/{EPOCHS}]")
    model.train()
    train_loss, train_correct = 0, 0
    total_train = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * inputs.size(0)
        train_correct += (outputs.argmax(1) == labels).sum().item()
        total_train += labels.size(0)

    train_loss /= total_train
    train_accuracy = train_correct / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    # ✅ 검증 단계
    model.eval()
    valid_loss, valid_correct = 0, 0
    total_valid = 0
    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)
            valid_correct += (outputs.argmax(1) == labels).sum().item()
            total_valid += labels.size(0)
    
    valid_loss /= total_valid
    valid_accuracy = valid_correct / total_valid
    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_accuracy)
    
    print(f"📉 Train Loss: {train_loss:.4f} | 🎯 Train Accuracy: {train_accuracy:.4f} | 📉 Valid Loss: {valid_loss:.4f} | 🎯 Valid Accuracy: {valid_accuracy:.4f}")
    
    # ✅ 최고 검증 정확도 모델 저장
    if valid_accuracy > best_valid_accuracy:
        best_valid_accuracy = valid_accuracy
        best_epoch_info = (epoch+1, train_loss, train_accuracy, valid_loss, valid_accuracy)
        best_model_path = os.path.join(model_dir, "best_category_model.pth")
        torch.save(model.state_dict(), best_model_path)
        print(f"🎯 새로운 최고 모델 저장됨! (Epoch {epoch+1}, Accuracy: {best_valid_accuracy:.4f})")

# ✅ 최적 에포크 정보 출력
if best_epoch_info:
    print("\n🔥 학습 종료! 가장 높은 검증 정확도를 기록한 에포크 🔥")
    print(f"✅ Best Epoch: {best_epoch_info[0]}")
    print(f"📉 Best Train Loss: {best_epoch_info[1]:.4f}")
    print(f"🎯 Best Train Accuracy: {best_epoch_info[2]:.4f}")
    print(f"📉 Best Valid Loss: {best_epoch_info[3]:.4f}")
    print(f"🎯 Best Valid Accuracy: {best_epoch_info[4]:.4f}")

# ✅ 결과 CSV 저장
df = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Train Loss': train_losses,
    'Valid Loss': valid_losses,
    'Train Accuracy': train_accuracies,
    'Valid Accuracy': valid_accuracies
})
df.to_csv(csv_path, index=False)
print(f"📄 학습 결과 CSV 저장됨: {csv_path}")
# Out:
# ✅ CUDA Available: True
# ✅ 사용 중인 GPU: Quadro RTX 4000
#
# 📢 Epoch [1/500]
# 📉 Train Loss: 0.8684 | 🎯 Train Accuracy: 0.7226 | 📉 Valid Loss: 0.5697 | 🎯 Valid Accuracy: 0.8223
# 🎯 새로운 최고 모델 저장됨! (Epoch 1, Accuracy: 0.8223)
#
# 📢 Epoch [2/500]
# 📉 Train Loss: 0.4873 | 🎯 Train Accuracy: 0.8419 | 📉 Valid Loss: 0.4848 | 🎯 Valid Accuracy: 0.8523
# 🎯 새로운 최고 모델 저장됨! (Epoch 2, Accuracy: 0.8523)
#
# 📢 Epoch [3/500]
# 📉 Train Loss: 0.3650 | 🎯 Train Accuracy: 0.8816 | 📉 Valid Loss: 0.5438 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [4/500]
# 📉 Train Loss: 0.2719 | 🎯 Train Accuracy: 0.9128 | 📉 Valid Loss: 0.5950 | 🎯 Valid Accuracy: 0.8387
#
# 📢 Epoch [5/500]
# 📉 Train Loss: 0.2210 | 🎯 Train Accuracy: 0.9267 | 📉 Valid Loss: 0.5961 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [6/500]
# 📉 Train Loss: 0.1912 | 🎯 Train Accuracy: 0.9361 | 📉 Valid Loss: 0.5762 | 🎯 Valid Accuracy: 0.8451
#
# 📢 Epoch [7/500]
# 📉 Train Loss: 0.1792 | 🎯 Train Accuracy: 0.9419 | 📉 Valid Loss: 0.5689 | 🎯 Valid Accuracy: 0.8499
#
# 📢 Epoch [8/500]
# 📉 Train Loss: 0.1574 | 🎯 Train Accuracy: 0.9497 | 📉 Valid Loss: 0.5495 | 🎯 Valid Accuracy: 0.8611
# 🎯 새로운 최고 모델 저장됨! (Epoch 8, Accuracy: 0.8611)
#
# 📢 Epoch [9/500]
# 📉 Train Loss: 0.1440 | 🎯 Train Accuracy: 0.9516 | 📉 Valid Loss: 0.6147 | 🎯 Valid Accuracy: 0.8495
#
# 📢 Epoch [10/500]
# 📉 Train Loss: 0.1308 | 🎯 Train Accuracy: 0.9557 | 📉 Valid Loss: 0.5703 | 🎯 Valid Accuracy: 0.8555
#
# 📢 Epoch [11/500]
# 📉 Train Loss: 0.0990 | 🎯 Train Accuracy: 0.9650 | 📉 Valid Loss: 0.6753 | 🎯 Valid Accuracy: 0.8455
#
# 📢 Epoch [12/500]
# 📉 Train Loss: 0.0939 | 🎯 Train Accuracy: 0.9690 | 📉 Valid Loss: 0.8309 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [13/500]
# 📉 Train Loss: 0.1193 | 🎯 Train Accuracy: 0.9592 | 📉 Valid Loss: 0.6270 | 🎯 Valid Accuracy: 0.8527
#
# 📢 Epoch [14/500]
# 📉 Train Loss: 0.0896 | 🎯 Train Accuracy: 0.9704 | 📉 Valid Loss: 0.7222 | 🎯 Valid Accuracy: 0.8543
#
# 📢 Epoch [15/500]
# 📉 Train Loss: 0.0722 | 🎯 Train Accuracy: 0.9746 | 📉 Valid Loss: 0.7207 | 🎯 Valid Accuracy: 0.8491
#
# 📢 Epoch [16/500]
# 📉 Train Loss: 0.1177 | 🎯 Train Accuracy: 0.9632 | 📉 Valid Loss: 0.7049 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [17/500]
# 📉 Train Loss: 0.0782 | 🎯 Train Accuracy: 0.9730 | 📉 Valid Loss: 0.6701 | 🎯 Valid Accuracy: 0.8531
#
# 📢 Epoch [18/500]
# 📉 Train Loss: 0.0722 | 🎯 Train Accuracy: 0.9773 | 📉 Valid Loss: 0.6922 | 🎯 Valid Accuracy: 0.8603
#
# 📢 Epoch [19/500]
# 📉 Train Loss: 0.0806 | 🎯 Train Accuracy: 0.9731 | 📉 Valid Loss: 0.7000 | 🎯 Valid Accuracy: 0.8559
#
# 📢 Epoch [20/500]
# 📉 Train Loss: 0.0781 | 🎯 Train Accuracy: 0.9739 | 📉 Valid Loss: 0.7812 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [21/500]
# 📉 Train Loss: 0.0938 | 🎯 Train Accuracy: 0.9716 | 📉 Valid Loss: 0.6824 | 🎯 Valid Accuracy: 0.8531
#
# 📢 Epoch [22/500]
# 📉 Train Loss: 0.0551 | 🎯 Train Accuracy: 0.9830 | 📉 Valid Loss: 0.8055 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [23/500]
# 📉 Train Loss: 0.0802 | 🎯 Train Accuracy: 0.9750 | 📉 Valid Loss: 0.7170 | 🎯 Valid Accuracy: 0.8627
# 🎯 새로운 최고 모델 저장됨! (Epoch 23, Accuracy: 0.8627)
#
# 📢 Epoch [24/500]
# 📉 Train Loss: 0.0731 | 🎯 Train Accuracy: 0.9765 | 📉 Valid Loss: 0.6810 | 🎯 Valid Accuracy: 0.8547
#
# 📢 Epoch [25/500]
# 📉 Train Loss: 0.0582 | 🎯 Train Accuracy: 0.9810 | 📉 Valid Loss: 0.7435 | 🎯 Valid Accuracy: 0.8411
#
# 📢 Epoch [26/500]
# 📉 Train Loss: 0.0660 | 🎯 Train Accuracy: 0.9795 | 📉 Valid Loss: 0.7669 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [27/500]
# 📉 Train Loss: 0.0679 | 🎯 Train Accuracy: 0.9786 | 📉 Valid Loss: 0.8029 | 🎯 Valid Accuracy: 0.8495
#
# 📢 Epoch [28/500]
# 📉 Train Loss: 0.0655 | 🎯 Train Accuracy: 0.9786 | 📉 Valid Loss: 0.7549 | 🎯 Valid Accuracy: 0.8511
#
# 📢 Epoch [29/500]
# 📉 Train Loss: 0.0495 | 🎯 Train Accuracy: 0.9845 | 📉 Valid Loss: 0.8086 | 🎯 Valid Accuracy: 0.8487
#
# 📢 Epoch [30/500]
# 📉 Train Loss: 0.0547 | 🎯 Train Accuracy: 0.9830 | 📉 Valid Loss: 0.7397 | 🎯 Valid Accuracy: 0.8503
#
# 📢 Epoch [31/500]
# 📉 Train Loss: 0.0646 | 🎯 Train Accuracy: 0.9790 | 📉 Valid Loss: 0.7451 | 🎯 Valid Accuracy: 0.8419
#
# 📢 Epoch [32/500]
# 📉 Train Loss: 0.0535 | 🎯 Train Accuracy: 0.9827 | 📉 Valid Loss: 0.7812 | 🎯 Valid Accuracy: 0.8527
#
# 📢 Epoch [33/500]
# 📉 Train Loss: 0.0553 | 🎯 Train Accuracy: 0.9815 | 📉 Valid Loss: 0.7548 | 🎯 Valid Accuracy: 0.8563
#
# 📢 Epoch [34/500]
# 📉 Train Loss: 0.0717 | 🎯 Train Accuracy: 0.9773 | 📉 Valid Loss: 0.7070 | 🎯 Valid Accuracy: 0.8519
#
# 📢 Epoch [35/500]
# 📉 Train Loss: 0.0503 | 🎯 Train Accuracy: 0.9843 | 📉 Valid Loss: 0.6581 | 🎯 Valid Accuracy: 0.8535
#
# 📢 Epoch [36/500]
# 📉 Train Loss: 0.0360 | 🎯 Train Accuracy: 0.9893 | 📉 Valid Loss: 0.7540 | 🎯 Valid Accuracy: 0.8507
#
# 📢 Epoch [37/500]
# 📉 Train Loss: 0.0409 | 🎯 Train Accuracy: 0.9880 | 📉 Valid Loss: 0.7576 | 🎯 Valid Accuracy: 0.8503
#
# 📢 Epoch [38/500]
# 📉 Train Loss: 0.0551 | 🎯 Train Accuracy: 0.9812 | 📉 Valid Loss: 0.7716 | 🎯 Valid Accuracy: 0.8467
#
# 📢 Epoch [39/500]
# 📉 Train Loss: 0.0486 | 🎯 Train Accuracy: 0.9842 | 📉 Valid Loss: 0.8783 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [40/500]
# 📉 Train Loss: 0.0432 | 🎯 Train Accuracy: 0.9853 | 📉 Valid Loss: 0.7954 | 🎯 Valid Accuracy: 0.8483
#
# 📢 Epoch [41/500]
# 📉 Train Loss: 0.0516 | 🎯 Train Accuracy: 0.9843 | 📉 Valid Loss: 0.8831 | 🎯 Valid Accuracy: 0.8427
#
# 📢 Epoch [42/500]
# 📉 Train Loss: 0.0475 | 🎯 Train Accuracy: 0.9858 | 📉 Valid Loss: 0.8406 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [43/500]
# 📉 Train Loss: 0.0447 | 🎯 Train Accuracy: 0.9858 | 📉 Valid Loss: 0.7720 | 🎯 Valid Accuracy: 0.8487
#
# 📢 Epoch [44/500]
# 📉 Train Loss: 0.0444 | 🎯 Train Accuracy: 0.9861 | 📉 Valid Loss: 0.8199 | 🎯 Valid Accuracy: 0.8451
#
# 📢 Epoch [45/500]
# 📉 Train Loss: 0.0458 | 🎯 Train Accuracy: 0.9852 | 📉 Valid Loss: 0.8003 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [46/500]
# 📉 Train Loss: 0.0267 | 🎯 Train Accuracy: 0.9915 | 📉 Valid Loss: 1.0475 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [47/500]
# 📉 Train Loss: 0.0408 | 🎯 Train Accuracy: 0.9875 | 📉 Valid Loss: 0.8508 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [48/500]
# 📉 Train Loss: 0.0450 | 🎯 Train Accuracy: 0.9853 | 📉 Valid Loss: 0.8094 | 🎯 Valid Accuracy: 0.8563
#
# 📢 Epoch [49/500]
# 📉 Train Loss: 0.0437 | 🎯 Train Accuracy: 0.9854 | 📉 Valid Loss: 0.8141 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [50/500]
# 📉 Train Loss: 0.0328 | 🎯 Train Accuracy: 0.9892 | 📉 Valid Loss: 0.8419 | 🎯 Valid Accuracy: 0.8515
#
# 📢 Epoch [51/500]
# 📉 Train Loss: 0.0291 | 🎯 Train Accuracy: 0.9909 | 📉 Valid Loss: 0.7937 | 🎯 Valid Accuracy: 0.8543
#
# 📢 Epoch [52/500]
# 📉 Train Loss: 0.0246 | 🎯 Train Accuracy: 0.9920 | 📉 Valid Loss: 0.8875 | 🎯 Valid Accuracy: 0.8479
#
# 📢 Epoch [53/500]
# 📉 Train Loss: 0.0322 | 🎯 Train Accuracy: 0.9896 | 📉 Valid Loss: 0.8251 | 🎯 Valid Accuracy: 0.8503
#
# 📢 Epoch [54/500]
# 📉 Train Loss: 0.0590 | 🎯 Train Accuracy: 0.9816 | 📉 Valid Loss: 0.8161 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [55/500]
# 📉 Train Loss: 0.0404 | 🎯 Train Accuracy: 0.9868 | 📉 Valid Loss: 0.8890 | 🎯 Valid Accuracy: 0.8447
#
# 📢 Epoch [56/500]
# 📉 Train Loss: 0.0395 | 🎯 Train Accuracy: 0.9873 | 📉 Valid Loss: 0.7883 | 🎯 Valid Accuracy: 0.8555
#
# 📢 Epoch [57/500]
# 📉 Train Loss: 0.0230 | 🎯 Train Accuracy: 0.9917 | 📉 Valid Loss: 0.8188 | 🎯 Valid Accuracy: 0.8591
#
# 📢 Epoch [58/500]
# 📉 Train Loss: 0.0435 | 🎯 Train Accuracy: 0.9856 | 📉 Valid Loss: 0.7677 | 🎯 Valid Accuracy: 0.8547
#
# 📢 Epoch [59/500]
# 📉 Train Loss: 0.0255 | 🎯 Train Accuracy: 0.9918 | 📉 Valid Loss: 0.8833 | 🎯 Valid Accuracy: 0.8527
#
# 📢 Epoch [60/500]
# 📉 Train Loss: 0.0406 | 🎯 Train Accuracy: 0.9867 | 📉 Valid Loss: 0.8989 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [61/500]
# 📉 Train Loss: 0.0288 | 🎯 Train Accuracy: 0.9901 | 📉 Valid Loss: 0.8130 | 🎯 Valid Accuracy: 0.8619
#
# 📢 Epoch [62/500]
# 📉 Train Loss: 0.0205 | 🎯 Train Accuracy: 0.9930 | 📉 Valid Loss: 0.8533 | 🎯 Valid Accuracy: 0.8527
#
# 📢 Epoch [63/500]
# 📉 Train Loss: 0.0351 | 🎯 Train Accuracy: 0.9888 | 📉 Valid Loss: 0.8618 | 🎯 Valid Accuracy: 0.8443
#
# 📢 Epoch [64/500]
# 📉 Train Loss: 0.0392 | 🎯 Train Accuracy: 0.9874 | 📉 Valid Loss: 0.8735 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [65/500]
# 📉 Train Loss: 0.0275 | 🎯 Train Accuracy: 0.9910 | 📉 Valid Loss: 0.8566 | 🎯 Valid Accuracy: 0.8547
#
# 📢 Epoch [66/500]
# 📉 Train Loss: 0.0317 | 🎯 Train Accuracy: 0.9888 | 📉 Valid Loss: 0.8090 | 🎯 Valid Accuracy: 0.8479
#
# 📢 Epoch [67/500]
# 📉 Train Loss: 0.0369 | 🎯 Train Accuracy: 0.9878 | 📉 Valid Loss: 0.8395 | 🎯 Valid Accuracy: 0.8499
#
# 📢 Epoch [68/500]
# 📉 Train Loss: 0.0360 | 🎯 Train Accuracy: 0.9883 | 📉 Valid Loss: 0.8238 | 🎯 Valid Accuracy: 0.8371
#
# 📢 Epoch [69/500]
# 📉 Train Loss: 0.0214 | 🎯 Train Accuracy: 0.9924 | 📉 Valid Loss: 0.8315 | 🎯 Valid Accuracy: 0.8523
#
# 📢 Epoch [70/500]
# 📉 Train Loss: 0.0263 | 🎯 Train Accuracy: 0.9910 | 📉 Valid Loss: 0.8906 | 🎯 Valid Accuracy: 0.8495
#
# 📢 Epoch [71/500]
# 📉 Train Loss: 0.0254 | 🎯 Train Accuracy: 0.9923 | 📉 Valid Loss: 0.9081 | 🎯 Valid Accuracy: 0.8487
#
# 📢 Epoch [72/500]
# 📉 Train Loss: 0.0321 | 🎯 Train Accuracy: 0.9903 | 📉 Valid Loss: 0.8806 | 🎯 Valid Accuracy: 0.8407
#
# 📢 Epoch [73/500]
# 📉 Train Loss: 0.0328 | 🎯 Train Accuracy: 0.9907 | 📉 Valid Loss: 0.9069 | 🎯 Valid Accuracy: 0.8435
#
# 📢 Epoch [74/500]
# 📉 Train Loss: 0.0216 | 🎯 Train Accuracy: 0.9935 | 📉 Valid Loss: 0.9026 | 🎯 Valid Accuracy: 0.8515
#
# 📢 Epoch [75/500]
# 📉 Train Loss: 0.0258 | 🎯 Train Accuracy: 0.9911 | 📉 Valid Loss: 1.0654 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [76/500]
# 📉 Train Loss: 0.0326 | 🎯 Train Accuracy: 0.9889 | 📉 Valid Loss: 0.9265 | 🎯 Valid Accuracy: 0.8427
#
# 📢 Epoch [77/500]
# 📉 Train Loss: 0.0322 | 🎯 Train Accuracy: 0.9899 | 📉 Valid Loss: 0.9106 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [78/500]
# 📉 Train Loss: 0.0179 | 🎯 Train Accuracy: 0.9938 | 📉 Valid Loss: 0.9498 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [79/500]
# 📉 Train Loss: 0.0292 | 🎯 Train Accuracy: 0.9912 | 📉 Valid Loss: 0.8071 | 🎯 Valid Accuracy: 0.8495
#
# 📢 Epoch [80/500]
# 📉 Train Loss: 0.0386 | 🎯 Train Accuracy: 0.9875 | 📉 Valid Loss: 0.8981 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [81/500]
# 📉 Train Loss: 0.0299 | 🎯 Train Accuracy: 0.9896 | 📉 Valid Loss: 0.9849 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [82/500]
# 📉 Train Loss: 0.0286 | 🎯 Train Accuracy: 0.9904 | 📉 Valid Loss: 0.8116 | 🎯 Valid Accuracy: 0.8467
#
# 📢 Epoch [83/500]
# 📉 Train Loss: 0.0126 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 0.8655 | 🎯 Valid Accuracy: 0.8467
#
# 📢 Epoch [84/500]
# 📉 Train Loss: 0.0178 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 0.9599 | 🎯 Valid Accuracy: 0.8415
#
# 📢 Epoch [85/500]
# 📉 Train Loss: 0.0358 | 🎯 Train Accuracy: 0.9892 | 📉 Valid Loss: 0.9007 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [86/500]
# 📉 Train Loss: 0.0187 | 🎯 Train Accuracy: 0.9945 | 📉 Valid Loss: 0.9749 | 🎯 Valid Accuracy: 0.8359
#
# 📢 Epoch [87/500]
# 📉 Train Loss: 0.0240 | 🎯 Train Accuracy: 0.9923 | 📉 Valid Loss: 0.8936 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [88/500]
# 📉 Train Loss: 0.0245 | 🎯 Train Accuracy: 0.9917 | 📉 Valid Loss: 1.0115 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [89/500]
# 📉 Train Loss: 0.0324 | 🎯 Train Accuracy: 0.9896 | 📉 Valid Loss: 1.0010 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [90/500]
# 📉 Train Loss: 0.0262 | 🎯 Train Accuracy: 0.9924 | 📉 Valid Loss: 0.9850 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [91/500]
# 📉 Train Loss: 0.0313 | 🎯 Train Accuracy: 0.9908 | 📉 Valid Loss: 0.8943 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [92/500]
# 📉 Train Loss: 0.0246 | 🎯 Train Accuracy: 0.9928 | 📉 Valid Loss: 0.9058 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [93/500]
# 📉 Train Loss: 0.0144 | 🎯 Train Accuracy: 0.9957 | 📉 Valid Loss: 0.9366 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [94/500]
# 📉 Train Loss: 0.0241 | 🎯 Train Accuracy: 0.9928 | 📉 Valid Loss: 0.9547 | 🎯 Valid Accuracy: 0.8347
#
# 📢 Epoch [95/500]
# 📉 Train Loss: 0.0264 | 🎯 Train Accuracy: 0.9912 | 📉 Valid Loss: 0.8830 | 🎯 Valid Accuracy: 0.8407
#
# 📢 Epoch [96/500]
# 📉 Train Loss: 0.0239 | 🎯 Train Accuracy: 0.9917 | 📉 Valid Loss: 0.9455 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [97/500]
# 📉 Train Loss: 0.0188 | 🎯 Train Accuracy: 0.9934 | 📉 Valid Loss: 1.0001 | 🎯 Valid Accuracy: 0.8427
#
# 📢 Epoch [98/500]
# 📉 Train Loss: 0.0324 | 🎯 Train Accuracy: 0.9908 | 📉 Valid Loss: 0.9422 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [99/500]
# 📉 Train Loss: 0.0277 | 🎯 Train Accuracy: 0.9916 | 📉 Valid Loss: 0.9277 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [100/500]
# 📉 Train Loss: 0.0200 | 🎯 Train Accuracy: 0.9933 | 📉 Valid Loss: 0.9044 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [101/500]
# 📉 Train Loss: 0.0162 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 0.9691 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [102/500]
# 📉 Train Loss: 0.0158 | 🎯 Train Accuracy: 0.9948 | 📉 Valid Loss: 0.9406 | 🎯 Valid Accuracy: 0.8455
#
# 📢 Epoch [103/500]
# 📉 Train Loss: 0.0190 | 🎯 Train Accuracy: 0.9937 | 📉 Valid Loss: 0.8917 | 🎯 Valid Accuracy: 0.8463
#
# 📢 Epoch [104/500]
# 📉 Train Loss: 0.0139 | 🎯 Train Accuracy: 0.9947 | 📉 Valid Loss: 0.9653 | 🎯 Valid Accuracy: 0.8467
#
# 📢 Epoch [105/500]
# 📉 Train Loss: 0.0259 | 🎯 Train Accuracy: 0.9916 | 📉 Valid Loss: 0.9261 | 🎯 Valid Accuracy: 0.8431
#
# 📢 Epoch [106/500]
# 📉 Train Loss: 0.0270 | 🎯 Train Accuracy: 0.9914 | 📉 Valid Loss: 0.9340 | 🎯 Valid Accuracy: 0.8431
#
# 📢 Epoch [107/500]
# 📉 Train Loss: 0.0317 | 🎯 Train Accuracy: 0.9905 | 📉 Valid Loss: 0.9308 | 🎯 Valid Accuracy: 0.8259
#
# 📢 Epoch [108/500]
# 📉 Train Loss: 0.0236 | 🎯 Train Accuracy: 0.9928 | 📉 Valid Loss: 0.9055 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [109/500]
# 📉 Train Loss: 0.0208 | 🎯 Train Accuracy: 0.9930 | 📉 Valid Loss: 0.8985 | 🎯 Valid Accuracy: 0.8495
#
# 📢 Epoch [110/500]
# 📉 Train Loss: 0.0151 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 0.8897 | 🎯 Valid Accuracy: 0.8515
#
# 📢 Epoch [111/500]
# 📉 Train Loss: 0.0138 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 0.9760 | 🎯 Valid Accuracy: 0.8455
#
# 📢 Epoch [112/500]
# 📉 Train Loss: 0.0180 | 🎯 Train Accuracy: 0.9937 | 📉 Valid Loss: 0.9218 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [113/500]
# 📉 Train Loss: 0.0268 | 🎯 Train Accuracy: 0.9913 | 📉 Valid Loss: 0.9325 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [114/500]
# 📉 Train Loss: 0.0255 | 🎯 Train Accuracy: 0.9919 | 📉 Valid Loss: 0.9404 | 🎯 Valid Accuracy: 0.8443
#
# 📢 Epoch [115/500]
# 📉 Train Loss: 0.0217 | 🎯 Train Accuracy: 0.9938 | 📉 Valid Loss: 0.8937 | 🎯 Valid Accuracy: 0.8447
#
# 📢 Epoch [116/500]
# 📉 Train Loss: 0.0174 | 🎯 Train Accuracy: 0.9940 | 📉 Valid Loss: 1.0696 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [117/500]
# 📉 Train Loss: 0.0272 | 🎯 Train Accuracy: 0.9902 | 📉 Valid Loss: 1.0189 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [118/500]
# 📉 Train Loss: 0.0190 | 🎯 Train Accuracy: 0.9935 | 📉 Valid Loss: 0.9971 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [119/500]
# 📉 Train Loss: 0.0176 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 0.9077 | 🎯 Valid Accuracy: 0.8411
#
# 📢 Epoch [120/500]
# 📉 Train Loss: 0.0077 | 🎯 Train Accuracy: 0.9974 | 📉 Valid Loss: 0.9366 | 🎯 Valid Accuracy: 0.8547
#
# 📢 Epoch [121/500]
# 📉 Train Loss: 0.0174 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 1.1048 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [122/500]
# 📉 Train Loss: 0.0325 | 🎯 Train Accuracy: 0.9907 | 📉 Valid Loss: 1.0515 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [123/500]
# 📉 Train Loss: 0.0265 | 🎯 Train Accuracy: 0.9916 | 📉 Valid Loss: 1.0435 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [124/500]
# 📉 Train Loss: 0.0178 | 🎯 Train Accuracy: 0.9942 | 📉 Valid Loss: 1.0445 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [125/500]
# 📉 Train Loss: 0.0194 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.0536 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [126/500]
# 📉 Train Loss: 0.0108 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 0.9484 | 🎯 Valid Accuracy: 0.8547
#
# 📢 Epoch [127/500]
# 📉 Train Loss: 0.0134 | 🎯 Train Accuracy: 0.9951 | 📉 Valid Loss: 1.0698 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [128/500]
# 📉 Train Loss: 0.0322 | 🎯 Train Accuracy: 0.9895 | 📉 Valid Loss: 1.1167 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [129/500]
# 📉 Train Loss: 0.0154 | 🎯 Train Accuracy: 0.9938 | 📉 Valid Loss: 1.0520 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [130/500]
# 📉 Train Loss: 0.0174 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.0492 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [131/500]
# 📉 Train Loss: 0.0150 | 🎯 Train Accuracy: 0.9954 | 📉 Valid Loss: 1.2093 | 🎯 Valid Accuracy: 0.8191
#
# 📢 Epoch [132/500]
# 📉 Train Loss: 0.0154 | 🎯 Train Accuracy: 0.9949 | 📉 Valid Loss: 1.1294 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [133/500]
# 📉 Train Loss: 0.0162 | 🎯 Train Accuracy: 0.9943 | 📉 Valid Loss: 1.0345 | 🎯 Valid Accuracy: 0.8439
#
# 📢 Epoch [134/500]
# 📉 Train Loss: 0.0174 | 🎯 Train Accuracy: 0.9945 | 📉 Valid Loss: 1.0037 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [135/500]
# 📉 Train Loss: 0.0133 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 0.9473 | 🎯 Valid Accuracy: 0.8475
#
# 📢 Epoch [136/500]
# 📉 Train Loss: 0.0155 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 0.9259 | 🎯 Valid Accuracy: 0.8471
#
# 📢 Epoch [137/500]
# 📉 Train Loss: 0.0248 | 🎯 Train Accuracy: 0.9919 | 📉 Valid Loss: 0.9445 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [138/500]
# 📉 Train Loss: 0.0169 | 🎯 Train Accuracy: 0.9950 | 📉 Valid Loss: 0.9337 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [139/500]
# 📉 Train Loss: 0.0187 | 🎯 Train Accuracy: 0.9931 | 📉 Valid Loss: 0.9589 | 🎯 Valid Accuracy: 0.8467
#
# 📢 Epoch [140/500]
# 📉 Train Loss: 0.0136 | 🎯 Train Accuracy: 0.9951 | 📉 Valid Loss: 0.9782 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [141/500]
# 📉 Train Loss: 0.0325 | 🎯 Train Accuracy: 0.9888 | 📉 Valid Loss: 0.9171 | 🎯 Valid Accuracy: 0.8415
#
# 📢 Epoch [142/500]
# 📉 Train Loss: 0.0145 | 🎯 Train Accuracy: 0.9949 | 📉 Valid Loss: 1.0119 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [143/500]
# 📉 Train Loss: 0.0099 | 🎯 Train Accuracy: 0.9964 | 📉 Valid Loss: 0.9523 | 🎯 Valid Accuracy: 0.8551
#
# 📢 Epoch [144/500]
# 📉 Train Loss: 0.0114 | 🎯 Train Accuracy: 0.9960 | 📉 Valid Loss: 0.9712 | 🎯 Valid Accuracy: 0.8419
#
# 📢 Epoch [145/500]
# 📉 Train Loss: 0.0162 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 0.9800 | 🎯 Valid Accuracy: 0.8435
#
# 📢 Epoch [146/500]
# 📉 Train Loss: 0.0092 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.0262 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [147/500]
# 📉 Train Loss: 0.0170 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 1.1667 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [148/500]
# 📉 Train Loss: 0.0313 | 🎯 Train Accuracy: 0.9905 | 📉 Valid Loss: 0.9969 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [149/500]
# 📉 Train Loss: 0.0139 | 🎯 Train Accuracy: 0.9953 | 📉 Valid Loss: 1.0095 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [150/500]
# 📉 Train Loss: 0.0125 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.0361 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [151/500]
# 📉 Train Loss: 0.0128 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.0192 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [152/500]
# 📉 Train Loss: 0.0101 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.0273 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [153/500]
# 📉 Train Loss: 0.0251 | 🎯 Train Accuracy: 0.9937 | 📉 Valid Loss: 0.9782 | 🎯 Valid Accuracy: 0.8347
#
# 📢 Epoch [154/500]
# 📉 Train Loss: 0.0133 | 🎯 Train Accuracy: 0.9953 | 📉 Valid Loss: 0.9822 | 🎯 Valid Accuracy: 0.8463
#
# 📢 Epoch [155/500]
# 📉 Train Loss: 0.0143 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.0825 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [156/500]
# 📉 Train Loss: 0.0166 | 🎯 Train Accuracy: 0.9941 | 📉 Valid Loss: 1.1023 | 🎯 Valid Accuracy: 0.8411
#
# 📢 Epoch [157/500]
# 📉 Train Loss: 0.0139 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.1186 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [158/500]
# 📉 Train Loss: 0.0156 | 🎯 Train Accuracy: 0.9942 | 📉 Valid Loss: 1.1419 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [159/500]
# 📉 Train Loss: 0.0156 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.0607 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [160/500]
# 📉 Train Loss: 0.0146 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.1110 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [161/500]
# 📉 Train Loss: 0.0109 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.1066 | 🎯 Valid Accuracy: 0.8359
#
# 📢 Epoch [162/500]
# 📉 Train Loss: 0.0126 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.1113 | 🎯 Valid Accuracy: 0.8335
#
# 📢 Epoch [163/500]
# 📉 Train Loss: 0.0130 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.0288 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [164/500]
# 📉 Train Loss: 0.0127 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.0319 | 🎯 Valid Accuracy: 0.8443
#
# 📢 Epoch [165/500]
# 📉 Train Loss: 0.0137 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.0539 | 🎯 Valid Accuracy: 0.8387
#
# 📢 Epoch [166/500]
# 📉 Train Loss: 0.0134 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.1452 | 🎯 Valid Accuracy: 0.8407
#
# 📢 Epoch [167/500]
# 📉 Train Loss: 0.0215 | 🎯 Train Accuracy: 0.9933 | 📉 Valid Loss: 1.1015 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [168/500]
# 📉 Train Loss: 0.0208 | 🎯 Train Accuracy: 0.9933 | 📉 Valid Loss: 1.1553 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [169/500]
# 📉 Train Loss: 0.0135 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 0.9916 | 🎯 Valid Accuracy: 0.8443
#
# 📢 Epoch [170/500]
# 📉 Train Loss: 0.0061 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.1766 | 🎯 Valid Accuracy: 0.8387
#
# 📢 Epoch [171/500]
# 📉 Train Loss: 0.0175 | 🎯 Train Accuracy: 0.9949 | 📉 Valid Loss: 1.0717 | 🎯 Valid Accuracy: 0.8259
#
# 📢 Epoch [172/500]
# 📉 Train Loss: 0.0204 | 🎯 Train Accuracy: 0.9932 | 📉 Valid Loss: 1.0825 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [173/500]
# 📉 Train Loss: 0.0159 | 🎯 Train Accuracy: 0.9951 | 📉 Valid Loss: 1.0927 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [174/500]
# 📉 Train Loss: 0.0068 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.0895 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [175/500]
# 📉 Train Loss: 0.0102 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.0448 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [176/500]
# 📉 Train Loss: 0.0107 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.1074 | 🎯 Valid Accuracy: 0.8359
#
# 📢 Epoch [177/500]
# 📉 Train Loss: 0.0161 | 🎯 Train Accuracy: 0.9953 | 📉 Valid Loss: 1.1119 | 🎯 Valid Accuracy: 0.8287
#
# 📢 Epoch [178/500]
# 📉 Train Loss: 0.0239 | 🎯 Train Accuracy: 0.9919 | 📉 Valid Loss: 1.0624 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [179/500]
# 📉 Train Loss: 0.0177 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 1.0395 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [180/500]
# 📉 Train Loss: 0.0100 | 🎯 Train Accuracy: 0.9964 | 📉 Valid Loss: 1.0026 | 🎯 Valid Accuracy: 0.8407
#
# 📢 Epoch [181/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 0.9623 | 🎯 Valid Accuracy: 0.8419
#
# 📢 Epoch [182/500]
# 📉 Train Loss: 0.0116 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.1356 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [183/500]
# 📉 Train Loss: 0.0105 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.1357 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [184/500]
# 📉 Train Loss: 0.0157 | 🎯 Train Accuracy: 0.9943 | 📉 Valid Loss: 1.1021 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [185/500]
# 📉 Train Loss: 0.0154 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.0408 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [186/500]
# 📉 Train Loss: 0.0041 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.1031 | 🎯 Valid Accuracy: 0.8463
#
# 📢 Epoch [187/500]
# 📉 Train Loss: 0.0099 | 🎯 Train Accuracy: 0.9962 | 📉 Valid Loss: 1.1914 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [188/500]
# 📉 Train Loss: 0.0278 | 🎯 Train Accuracy: 0.9923 | 📉 Valid Loss: 1.1215 | 🎯 Valid Accuracy: 0.8227
#
# 📢 Epoch [189/500]
# 📉 Train Loss: 0.0117 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.0910 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [190/500]
# 📉 Train Loss: 0.0116 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.0853 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [191/500]
# 📉 Train Loss: 0.0130 | 🎯 Train Accuracy: 0.9964 | 📉 Valid Loss: 1.1409 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [192/500]
# 📉 Train Loss: 0.0097 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.1861 | 🎯 Valid Accuracy: 0.8435
#
# 📢 Epoch [193/500]
# 📉 Train Loss: 0.0177 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.2264 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [194/500]
# 📉 Train Loss: 0.0186 | 🎯 Train Accuracy: 0.9945 | 📉 Valid Loss: 1.1021 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [195/500]
# 📉 Train Loss: 0.0069 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.1111 | 🎯 Valid Accuracy: 0.8391
#
# 📢 Epoch [196/500]
# 📉 Train Loss: 0.0121 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.0901 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [197/500]
# 📉 Train Loss: 0.0130 | 🎯 Train Accuracy: 0.9962 | 📉 Valid Loss: 1.1448 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [198/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.2148 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [199/500]
# 📉 Train Loss: 0.0223 | 🎯 Train Accuracy: 0.9934 | 📉 Valid Loss: 1.0877 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [200/500]
# 📉 Train Loss: 0.0141 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.2064 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [201/500]
# 📉 Train Loss: 0.0146 | 🎯 Train Accuracy: 0.9949 | 📉 Valid Loss: 1.1016 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [202/500]
# 📉 Train Loss: 0.0101 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.2478 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [203/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.1598 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [204/500]
# 📉 Train Loss: 0.0141 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.1423 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [205/500]
# 📉 Train Loss: 0.0100 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.0954 | 🎯 Valid Accuracy: 0.8427
#
# 📢 Epoch [206/500]
# 📉 Train Loss: 0.0146 | 🎯 Train Accuracy: 0.9945 | 📉 Valid Loss: 1.1861 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [207/500]
# 📉 Train Loss: 0.0140 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.1518 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [208/500]
# 📉 Train Loss: 0.0134 | 🎯 Train Accuracy: 0.9951 | 📉 Valid Loss: 1.1560 | 🎯 Valid Accuracy: 0.8387
#
# 📢 Epoch [209/500]
# 📉 Train Loss: 0.0055 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.1402 | 🎯 Valid Accuracy: 0.8335
#
# 📢 Epoch [210/500]
# 📉 Train Loss: 0.0085 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.2026 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [211/500]
# 📉 Train Loss: 0.0126 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.1080 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [212/500]
# 📉 Train Loss: 0.0154 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.1624 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [213/500]
# 📉 Train Loss: 0.0115 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.0530 | 🎯 Valid Accuracy: 0.8423
#
# 📢 Epoch [214/500]
# 📉 Train Loss: 0.0094 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.1718 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [215/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.2091 | 🎯 Valid Accuracy: 0.8191
#
# 📢 Epoch [216/500]
# 📉 Train Loss: 0.0176 | 🎯 Train Accuracy: 0.9940 | 📉 Valid Loss: 1.1141 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [217/500]
# 📉 Train Loss: 0.0147 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.1704 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [218/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.2225 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [219/500]
# 📉 Train Loss: 0.0056 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.1441 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [220/500]
# 📉 Train Loss: 0.0152 | 🎯 Train Accuracy: 0.9950 | 📉 Valid Loss: 1.1584 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [221/500]
# 📉 Train Loss: 0.0099 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.1235 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [222/500]
# 📉 Train Loss: 0.0075 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.2822 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [223/500]
# 📉 Train Loss: 0.0182 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.0308 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [224/500]
# 📉 Train Loss: 0.0118 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.1003 | 🎯 Valid Accuracy: 0.8399
#
# 📢 Epoch [225/500]
# 📉 Train Loss: 0.0076 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.1460 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [226/500]
# 📉 Train Loss: 0.0150 | 🎯 Train Accuracy: 0.9948 | 📉 Valid Loss: 1.1001 | 🎯 Valid Accuracy: 0.8335
#
# 📢 Epoch [227/500]
# 📉 Train Loss: 0.0137 | 🎯 Train Accuracy: 0.9954 | 📉 Valid Loss: 1.0188 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [228/500]
# 📉 Train Loss: 0.0144 | 🎯 Train Accuracy: 0.9953 | 📉 Valid Loss: 1.2451 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [229/500]
# 📉 Train Loss: 0.0141 | 🎯 Train Accuracy: 0.9954 | 📉 Valid Loss: 1.1831 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [230/500]
# 📉 Train Loss: 0.0150 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.0469 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [231/500]
# 📉 Train Loss: 0.0125 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 0.9841 | 🎯 Valid Accuracy: 0.8415
#
# 📢 Epoch [232/500]
# 📉 Train Loss: 0.0059 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.0729 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [233/500]
# 📉 Train Loss: 0.0047 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.0958 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [234/500]
# 📉 Train Loss: 0.0059 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.1735 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [235/500]
# 📉 Train Loss: 0.0092 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.1785 | 🎯 Valid Accuracy: 0.8379
#
# 📢 Epoch [236/500]
# 📉 Train Loss: 0.0171 | 🎯 Train Accuracy: 0.9943 | 📉 Valid Loss: 1.2770 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [237/500]
# 📉 Train Loss: 0.0174 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 1.2843 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [238/500]
# 📉 Train Loss: 0.0142 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.2497 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [239/500]
# 📉 Train Loss: 0.0133 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.3508 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [240/500]
# 📉 Train Loss: 0.0078 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.2609 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [241/500]
# 📉 Train Loss: 0.0116 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.2111 | 🎯 Valid Accuracy: 0.8283
#
# 📢 Epoch [242/500]
# 📉 Train Loss: 0.0058 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.2073 | 🎯 Valid Accuracy: 0.8347
#
# 📢 Epoch [243/500]
# 📉 Train Loss: 0.0094 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.2771 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [244/500]
# 📉 Train Loss: 0.0166 | 🎯 Train Accuracy: 0.9947 | 📉 Valid Loss: 1.1955 | 🎯 Valid Accuracy: 0.8255
#
# 📢 Epoch [245/500]
# 📉 Train Loss: 0.0069 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.1322 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [246/500]
# 📉 Train Loss: 0.0022 | 🎯 Train Accuracy: 0.9992 | 📉 Valid Loss: 1.1685 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [247/500]
# 📉 Train Loss: 0.0084 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.2056 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [248/500]
# 📉 Train Loss: 0.0133 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.0967 | 🎯 Valid Accuracy: 0.8259
#
# 📢 Epoch [249/500]
# 📉 Train Loss: 0.0159 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.1787 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [250/500]
# 📉 Train Loss: 0.0118 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.1591 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [251/500]
# 📉 Train Loss: 0.0104 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.2924 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [252/500]
# 📉 Train Loss: 0.0061 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.2344 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [253/500]
# 📉 Train Loss: 0.0148 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.0911 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [254/500]
# 📉 Train Loss: 0.0060 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.1856 | 🎯 Valid Accuracy: 0.8391
#
# 📢 Epoch [255/500]
# 📉 Train Loss: 0.0028 | 🎯 Train Accuracy: 0.9991 | 📉 Valid Loss: 1.1433 | 🎯 Valid Accuracy: 0.8483
#
# 📢 Epoch [256/500]
# 📉 Train Loss: 0.0083 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.2174 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [257/500]
# 📉 Train Loss: 0.0120 | 🎯 Train Accuracy: 0.9957 | 📉 Valid Loss: 1.2018 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [258/500]
# 📉 Train Loss: 0.0123 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.3503 | 🎯 Valid Accuracy: 0.8119
#
# 📢 Epoch [259/500]
# 📉 Train Loss: 0.0158 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.2413 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [260/500]
# 📉 Train Loss: 0.0167 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.2044 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [261/500]
# 📉 Train Loss: 0.0128 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.2598 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [262/500]
# 📉 Train Loss: 0.0087 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.1102 | 🎯 Valid Accuracy: 0.8371
#
# 📢 Epoch [263/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.2037 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [264/500]
# 📉 Train Loss: 0.0045 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2127 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [265/500]
# 📉 Train Loss: 0.0072 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.3099 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [266/500]
# 📉 Train Loss: 0.0185 | 🎯 Train Accuracy: 0.9946 | 📉 Valid Loss: 1.1223 | 🎯 Valid Accuracy: 0.8287
#
# 📢 Epoch [267/500]
# 📉 Train Loss: 0.0147 | 🎯 Train Accuracy: 0.9954 | 📉 Valid Loss: 1.0734 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [268/500]
# 📉 Train Loss: 0.0076 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.0499 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [269/500]
# 📉 Train Loss: 0.0048 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.1916 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [270/500]
# 📉 Train Loss: 0.0120 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.2299 | 🎯 Valid Accuracy: 0.8123
#
# 📢 Epoch [271/500]
# 📉 Train Loss: 0.0183 | 🎯 Train Accuracy: 0.9941 | 📉 Valid Loss: 1.1390 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [272/500]
# 📉 Train Loss: 0.0094 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.2521 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [273/500]
# 📉 Train Loss: 0.0095 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.1722 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [274/500]
# 📉 Train Loss: 0.0039 | 🎯 Train Accuracy: 0.9986 | 📉 Valid Loss: 1.1423 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [275/500]
# 📉 Train Loss: 0.0020 | 🎯 Train Accuracy: 0.9991 | 📉 Valid Loss: 1.2068 | 🎯 Valid Accuracy: 0.8459
#
# 📢 Epoch [276/500]
# 📉 Train Loss: 0.0040 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3184 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [277/500]
# 📉 Train Loss: 0.0211 | 🎯 Train Accuracy: 0.9939 | 📉 Valid Loss: 1.2321 | 🎯 Valid Accuracy: 0.8215
#
# 📢 Epoch [278/500]
# 📉 Train Loss: 0.0156 | 🎯 Train Accuracy: 0.9944 | 📉 Valid Loss: 1.0853 | 🎯 Valid Accuracy: 0.8367
#
# 📢 Epoch [279/500]
# 📉 Train Loss: 0.0054 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.2680 | 🎯 Valid Accuracy: 0.8251
#
# 📢 Epoch [280/500]
# 📉 Train Loss: 0.0084 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.3138 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [281/500]
# 📉 Train Loss: 0.0115 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.2189 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [282/500]
# 📉 Train Loss: 0.0063 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.2120 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [283/500]
# 📉 Train Loss: 0.0043 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.2917 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [284/500]
# 📉 Train Loss: 0.0130 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.2854 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [285/500]
# 📉 Train Loss: 0.0152 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.2351 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [286/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.2994 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [287/500]
# 📉 Train Loss: 0.0117 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.3534 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [288/500]
# 📉 Train Loss: 0.0127 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.2131 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [289/500]
# 📉 Train Loss: 0.0067 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.2213 | 🎯 Valid Accuracy: 0.8383
#
# 📢 Epoch [290/500]
# 📉 Train Loss: 0.0067 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.1264 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [291/500]
# 📉 Train Loss: 0.0061 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.1038 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [292/500]
# 📉 Train Loss: 0.0062 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.2033 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [293/500]
# 📉 Train Loss: 0.0072 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.2077 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [294/500]
# 📉 Train Loss: 0.0072 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.1972 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [295/500]
# 📉 Train Loss: 0.0115 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.2915 | 🎯 Valid Accuracy: 0.8159
#
# 📢 Epoch [296/500]
# 📉 Train Loss: 0.0168 | 🎯 Train Accuracy: 0.9952 | 📉 Valid Loss: 1.1669 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [297/500]
# 📉 Train Loss: 0.0117 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.1220 | 🎯 Valid Accuracy: 0.8207
#
# 📢 Epoch [298/500]
# 📉 Train Loss: 0.0047 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.1998 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [299/500]
# 📉 Train Loss: 0.0040 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.1573 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [300/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.3140 | 🎯 Valid Accuracy: 0.8107
#
# 📢 Epoch [301/500]
# 📉 Train Loss: 0.0143 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.3382 | 🎯 Valid Accuracy: 0.8083
#
# 📢 Epoch [302/500]
# 📉 Train Loss: 0.0148 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.2088 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [303/500]
# 📉 Train Loss: 0.0077 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.2350 | 🎯 Valid Accuracy: 0.8287
#
# 📢 Epoch [304/500]
# 📉 Train Loss: 0.0071 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.2062 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [305/500]
# 📉 Train Loss: 0.0048 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.3294 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [306/500]
# 📉 Train Loss: 0.0105 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.3996 | 🎯 Valid Accuracy: 0.8171
#
# 📢 Epoch [307/500]
# 📉 Train Loss: 0.0115 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.4387 | 🎯 Valid Accuracy: 0.8167
#
# 📢 Epoch [308/500]
# 📉 Train Loss: 0.0108 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.2665 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [309/500]
# 📉 Train Loss: 0.0058 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2518 | 🎯 Valid Accuracy: 0.8207
#
# 📢 Epoch [310/500]
# 📉 Train Loss: 0.0063 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2375 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [311/500]
# 📉 Train Loss: 0.0067 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.1568 | 🎯 Valid Accuracy: 0.8335
#
# 📢 Epoch [312/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9974 | 📉 Valid Loss: 1.2820 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [313/500]
# 📉 Train Loss: 0.0106 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.1977 | 🎯 Valid Accuracy: 0.8255
#
# 📢 Epoch [314/500]
# 📉 Train Loss: 0.0076 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.2014 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [315/500]
# 📉 Train Loss: 0.0116 | 🎯 Train Accuracy: 0.9962 | 📉 Valid Loss: 1.1797 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [316/500]
# 📉 Train Loss: 0.0107 | 🎯 Train Accuracy: 0.9961 | 📉 Valid Loss: 1.2723 | 🎯 Valid Accuracy: 0.8207
#
# 📢 Epoch [317/500]
# 📉 Train Loss: 0.0131 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.2044 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [318/500]
# 📉 Train Loss: 0.0060 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.2623 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [319/500]
# 📉 Train Loss: 0.0117 | 🎯 Train Accuracy: 0.9960 | 📉 Valid Loss: 1.2933 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [320/500]
# 📉 Train Loss: 0.0100 | 🎯 Train Accuracy: 0.9965 | 📉 Valid Loss: 1.2543 | 🎯 Valid Accuracy: 0.8203
#
# 📢 Epoch [321/500]
# 📉 Train Loss: 0.0081 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2683 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [322/500]
# 📉 Train Loss: 0.0044 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.2880 | 🎯 Valid Accuracy: 0.8187
#
# 📢 Epoch [323/500]
# 📉 Train Loss: 0.0036 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.2957 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [324/500]
# 📉 Train Loss: 0.0096 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.3207 | 🎯 Valid Accuracy: 0.8211
#
# 📢 Epoch [325/500]
# 📉 Train Loss: 0.0125 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.2495 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [326/500]
# 📉 Train Loss: 0.0053 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.3525 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [327/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.3792 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [328/500]
# 📉 Train Loss: 0.0148 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.2363 | 🎯 Valid Accuracy: 0.8175
#
# 📢 Epoch [329/500]
# 📉 Train Loss: 0.0118 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.2256 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [330/500]
# 📉 Train Loss: 0.0086 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.1478 | 🎯 Valid Accuracy: 0.8387
#
# 📢 Epoch [331/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.1844 | 🎯 Valid Accuracy: 0.8287
#
# 📢 Epoch [332/500]
# 📉 Train Loss: 0.0067 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.2048 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [333/500]
# 📉 Train Loss: 0.0041 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.2922 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [334/500]
# 📉 Train Loss: 0.0030 | 🎯 Train Accuracy: 0.9990 | 📉 Valid Loss: 1.2482 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [335/500]
# 📉 Train Loss: 0.0034 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.3029 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [336/500]
# 📉 Train Loss: 0.0154 | 🎯 Train Accuracy: 0.9958 | 📉 Valid Loss: 1.3442 | 🎯 Valid Accuracy: 0.8127
#
# 📢 Epoch [337/500]
# 📉 Train Loss: 0.0173 | 🎯 Train Accuracy: 0.9954 | 📉 Valid Loss: 1.1759 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [338/500]
# 📉 Train Loss: 0.0056 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.2575 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [339/500]
# 📉 Train Loss: 0.0047 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.2098 | 🎯 Valid Accuracy: 0.8347
#
# 📢 Epoch [340/500]
# 📉 Train Loss: 0.0056 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.2935 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [341/500]
# 📉 Train Loss: 0.0044 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2537 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [342/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.2090 | 🎯 Valid Accuracy: 0.8283
#
# 📢 Epoch [343/500]
# 📉 Train Loss: 0.0126 | 🎯 Train Accuracy: 0.9960 | 📉 Valid Loss: 1.2924 | 🎯 Valid Accuracy: 0.8179
#
# 📢 Epoch [344/500]
# 📉 Train Loss: 0.0055 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3179 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [345/500]
# 📉 Train Loss: 0.0079 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.4121 | 🎯 Valid Accuracy: 0.8143
#
# 📢 Epoch [346/500]
# 📉 Train Loss: 0.0121 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.4233 | 🎯 Valid Accuracy: 0.8111
#
# 📢 Epoch [347/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.4040 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [348/500]
# 📉 Train Loss: 0.0033 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.4541 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [349/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.4052 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [350/500]
# 📉 Train Loss: 0.0153 | 🎯 Train Accuracy: 0.9950 | 📉 Valid Loss: 1.3797 | 🎯 Valid Accuracy: 0.8167
#
# 📢 Epoch [351/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.3659 | 🎯 Valid Accuracy: 0.8175
#
# 📢 Epoch [352/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.3305 | 🎯 Valid Accuracy: 0.8283
#
# 📢 Epoch [353/500]
# 📉 Train Loss: 0.0078 | 🎯 Train Accuracy: 0.9973 | 📉 Valid Loss: 1.3558 | 🎯 Valid Accuracy: 0.8163
#
# 📢 Epoch [354/500]
# 📉 Train Loss: 0.0057 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3704 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [355/500]
# 📉 Train Loss: 0.0077 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.2808 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [356/500]
# 📉 Train Loss: 0.0036 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3121 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [357/500]
# 📉 Train Loss: 0.0035 | 🎯 Train Accuracy: 0.9993 | 📉 Valid Loss: 1.4500 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [358/500]
# 📉 Train Loss: 0.0101 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.4107 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [359/500]
# 📉 Train Loss: 0.0136 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.3594 | 🎯 Valid Accuracy: 0.8095
#
# 📢 Epoch [360/500]
# 📉 Train Loss: 0.0046 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.4546 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [361/500]
# 📉 Train Loss: 0.0090 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.3767 | 🎯 Valid Accuracy: 0.8195
#
# 📢 Epoch [362/500]
# 📉 Train Loss: 0.0105 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.3877 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [363/500]
# 📉 Train Loss: 0.0082 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.3548 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [364/500]
# 📉 Train Loss: 0.0073 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.2534 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [365/500]
# 📉 Train Loss: 0.0031 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3068 | 🎯 Valid Accuracy: 0.8283
#
# 📢 Epoch [366/500]
# 📉 Train Loss: 0.0044 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.4216 | 🎯 Valid Accuracy: 0.8227
#
# 📢 Epoch [367/500]
# 📉 Train Loss: 0.0079 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.3580 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [368/500]
# 📉 Train Loss: 0.0122 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.3256 | 🎯 Valid Accuracy: 0.8203
#
# 📢 Epoch [369/500]
# 📉 Train Loss: 0.0042 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.1743 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [370/500]
# 📉 Train Loss: 0.0020 | 🎯 Train Accuracy: 0.9993 | 📉 Valid Loss: 1.2570 | 🎯 Valid Accuracy: 0.8259
#
# 📢 Epoch [371/500]
# 📉 Train Loss: 0.0132 | 🎯 Train Accuracy: 0.9956 | 📉 Valid Loss: 1.3572 | 🎯 Valid Accuracy: 0.8111
#
# 📢 Epoch [372/500]
# 📉 Train Loss: 0.0088 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2590 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [373/500]
# 📉 Train Loss: 0.0056 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3277 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [374/500]
# 📉 Train Loss: 0.0075 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.3620 | 🎯 Valid Accuracy: 0.8155
#
# 📢 Epoch [375/500]
# 📉 Train Loss: 0.0130 | 🎯 Train Accuracy: 0.9959 | 📉 Valid Loss: 1.3790 | 🎯 Valid Accuracy: 0.8151
#
# 📢 Epoch [376/500]
# 📉 Train Loss: 0.0095 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.3553 | 🎯 Valid Accuracy: 0.8211
#
# 📢 Epoch [377/500]
# 📉 Train Loss: 0.0071 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.2738 | 🎯 Valid Accuracy: 0.8359
#
# 📢 Epoch [378/500]
# 📉 Train Loss: 0.0091 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.2475 | 🎯 Valid Accuracy: 0.8195
#
# 📢 Epoch [379/500]
# 📉 Train Loss: 0.0089 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.1242 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [380/500]
# 📉 Train Loss: 0.0044 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2353 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [381/500]
# 📉 Train Loss: 0.0018 | 🎯 Train Accuracy: 0.9994 | 📉 Valid Loss: 1.2201 | 🎯 Valid Accuracy: 0.8435
#
# 📢 Epoch [382/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9986 | 📉 Valid Loss: 1.2493 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [383/500]
# 📉 Train Loss: 0.0048 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.3536 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [384/500]
# 📉 Train Loss: 0.0075 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3531 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [385/500]
# 📉 Train Loss: 0.0071 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.2709 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [386/500]
# 📉 Train Loss: 0.0065 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3347 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [387/500]
# 📉 Train Loss: 0.0105 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.2893 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [388/500]
# 📉 Train Loss: 0.0108 | 🎯 Train Accuracy: 0.9964 | 📉 Valid Loss: 1.2592 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [389/500]
# 📉 Train Loss: 0.0071 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.2556 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [390/500]
# 📉 Train Loss: 0.0032 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.3322 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [391/500]
# 📉 Train Loss: 0.0033 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.3886 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [392/500]
# 📉 Train Loss: 0.0090 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2508 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [393/500]
# 📉 Train Loss: 0.0102 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2252 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [394/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.2364 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [395/500]
# 📉 Train Loss: 0.0076 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.3048 | 🎯 Valid Accuracy: 0.8163
#
# 📢 Epoch [396/500]
# 📉 Train Loss: 0.0071 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.1598 | 🎯 Valid Accuracy: 0.8403
#
# 📢 Epoch [397/500]
# 📉 Train Loss: 0.0016 | 🎯 Train Accuracy: 0.9994 | 📉 Valid Loss: 1.3239 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [398/500]
# 📉 Train Loss: 0.0016 | 🎯 Train Accuracy: 0.9995 | 📉 Valid Loss: 1.2650 | 🎯 Valid Accuracy: 0.8371
#
# 📢 Epoch [399/500]
# 📉 Train Loss: 0.0043 | 🎯 Train Accuracy: 0.9986 | 📉 Valid Loss: 1.3061 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [400/500]
# 📉 Train Loss: 0.0113 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.3228 | 🎯 Valid Accuracy: 0.8215
#
# 📢 Epoch [401/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.3574 | 🎯 Valid Accuracy: 0.8207
#
# 📢 Epoch [402/500]
# 📉 Train Loss: 0.0093 | 🎯 Train Accuracy: 0.9970 | 📉 Valid Loss: 1.2770 | 🎯 Valid Accuracy: 0.8327
#
# 📢 Epoch [403/500]
# 📉 Train Loss: 0.0057 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.2885 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [404/500]
# 📉 Train Loss: 0.0112 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.2453 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [405/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.3274 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [406/500]
# 📉 Train Loss: 0.0107 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.1909 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [407/500]
# 📉 Train Loss: 0.0122 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.1268 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [408/500]
# 📉 Train Loss: 0.0088 | 🎯 Train Accuracy: 0.9974 | 📉 Valid Loss: 1.0900 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [409/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.2389 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [410/500]
# 📉 Train Loss: 0.0031 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.2525 | 🎯 Valid Accuracy: 0.8355
#
# 📢 Epoch [411/500]
# 📉 Train Loss: 0.0024 | 🎯 Train Accuracy: 0.9994 | 📉 Valid Loss: 1.2522 | 🎯 Valid Accuracy: 0.8375
#
# 📢 Epoch [412/500]
# 📉 Train Loss: 0.0025 | 🎯 Train Accuracy: 0.9992 | 📉 Valid Loss: 1.3215 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [413/500]
# 📉 Train Loss: 0.0049 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.3725 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [414/500]
# 📉 Train Loss: 0.0050 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.3084 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [415/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.2971 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [416/500]
# 📉 Train Loss: 0.0223 | 🎯 Train Accuracy: 0.9931 | 📉 Valid Loss: 1.3141 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [417/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.2318 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [418/500]
# 📉 Train Loss: 0.0031 | 🎯 Train Accuracy: 0.9991 | 📉 Valid Loss: 1.2390 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [419/500]
# 📉 Train Loss: 0.0063 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.2392 | 🎯 Valid Accuracy: 0.8335
#
# 📢 Epoch [420/500]
# 📉 Train Loss: 0.0022 | 🎯 Train Accuracy: 0.9995 | 📉 Valid Loss: 1.2701 | 🎯 Valid Accuracy: 0.8395
#
# 📢 Epoch [421/500]
# 📉 Train Loss: 0.0066 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.3149 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [422/500]
# 📉 Train Loss: 0.0136 | 🎯 Train Accuracy: 0.9960 | 📉 Valid Loss: 1.2864 | 🎯 Valid Accuracy: 0.8195
#
# 📢 Epoch [423/500]
# 📉 Train Loss: 0.0122 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.2057 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [424/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9974 | 📉 Valid Loss: 1.3304 | 🎯 Valid Accuracy: 0.8243
#
# 📢 Epoch [425/500]
# 📉 Train Loss: 0.0088 | 🎯 Train Accuracy: 0.9974 | 📉 Valid Loss: 1.3539 | 🎯 Valid Accuracy: 0.8223
#
# 📢 Epoch [426/500]
# 📉 Train Loss: 0.0058 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.1710 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [427/500]
# 📉 Train Loss: 0.0019 | 🎯 Train Accuracy: 0.9993 | 📉 Valid Loss: 1.2382 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [428/500]
# 📉 Train Loss: 0.0025 | 🎯 Train Accuracy: 0.9994 | 📉 Valid Loss: 1.2647 | 🎯 Valid Accuracy: 0.8347
#
# 📢 Epoch [429/500]
# 📉 Train Loss: 0.0055 | 🎯 Train Accuracy: 0.9979 | 📉 Valid Loss: 1.4269 | 🎯 Valid Accuracy: 0.8271
#
# 📢 Epoch [430/500]
# 📉 Train Loss: 0.0107 | 🎯 Train Accuracy: 0.9963 | 📉 Valid Loss: 1.4493 | 🎯 Valid Accuracy: 0.8251
#
# 📢 Epoch [431/500]
# 📉 Train Loss: 0.0099 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.4389 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [432/500]
# 📉 Train Loss: 0.0102 | 🎯 Train Accuracy: 0.9964 | 📉 Valid Loss: 1.2874 | 🎯 Valid Accuracy: 0.8219
#
# 📢 Epoch [433/500]
# 📉 Train Loss: 0.0107 | 🎯 Train Accuracy: 0.9967 | 📉 Valid Loss: 1.1990 | 🎯 Valid Accuracy: 0.8319
#
# 📢 Epoch [434/500]
# 📉 Train Loss: 0.0034 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.2980 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [435/500]
# 📉 Train Loss: 0.0021 | 🎯 Train Accuracy: 0.9996 | 📉 Valid Loss: 1.3314 | 🎯 Valid Accuracy: 0.8351
#
# 📢 Epoch [436/500]
# 📉 Train Loss: 0.0048 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.4094 | 🎯 Valid Accuracy: 0.8235
#
# 📢 Epoch [437/500]
# 📉 Train Loss: 0.0085 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.4641 | 🎯 Valid Accuracy: 0.8155
#
# 📢 Epoch [438/500]
# 📉 Train Loss: 0.0152 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.3591 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [439/500]
# 📉 Train Loss: 0.0079 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.2899 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [440/500]
# 📉 Train Loss: 0.0038 | 🎯 Train Accuracy: 0.9986 | 📉 Valid Loss: 1.2687 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [441/500]
# 📉 Train Loss: 0.0043 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.2914 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [442/500]
# 📉 Train Loss: 0.0042 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.3270 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [443/500]
# 📉 Train Loss: 0.0039 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.3436 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [444/500]
# 📉 Train Loss: 0.0028 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3356 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [445/500]
# 📉 Train Loss: 0.0018 | 🎯 Train Accuracy: 0.9995 | 📉 Valid Loss: 1.4634 | 🎯 Valid Accuracy: 0.8283
#
# 📢 Epoch [446/500]
# 📉 Train Loss: 0.0092 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.6374 | 🎯 Valid Accuracy: 0.8159
#
# 📢 Epoch [447/500]
# 📉 Train Loss: 0.0183 | 🎯 Train Accuracy: 0.9945 | 📉 Valid Loss: 1.4596 | 🎯 Valid Accuracy: 0.8143
#
# 📢 Epoch [448/500]
# 📉 Train Loss: 0.0113 | 🎯 Train Accuracy: 0.9968 | 📉 Valid Loss: 1.2252 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [449/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.2709 | 🎯 Valid Accuracy: 0.8275
#
# 📢 Epoch [450/500]
# 📉 Train Loss: 0.0037 | 🎯 Train Accuracy: 0.9984 | 📉 Valid Loss: 1.3486 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [451/500]
# 📉 Train Loss: 0.0022 | 🎯 Train Accuracy: 0.9991 | 📉 Valid Loss: 1.3694 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [452/500]
# 📉 Train Loss: 0.0037 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.3690 | 🎯 Valid Accuracy: 0.8359
#
# 📢 Epoch [453/500]
# 📉 Train Loss: 0.0040 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.4744 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [454/500]
# 📉 Train Loss: 0.0057 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.4688 | 🎯 Valid Accuracy: 0.8311
#
# 📢 Epoch [455/500]
# 📉 Train Loss: 0.0156 | 🎯 Train Accuracy: 0.9957 | 📉 Valid Loss: 1.2328 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [456/500]
# 📉 Train Loss: 0.0076 | 🎯 Train Accuracy: 0.9978 | 📉 Valid Loss: 1.2326 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [457/500]
# 📉 Train Loss: 0.0017 | 🎯 Train Accuracy: 0.9997 | 📉 Valid Loss: 1.2899 | 🎯 Valid Accuracy: 0.8435
#
# 📢 Epoch [458/500]
# 📉 Train Loss: 0.0041 | 🎯 Train Accuracy: 0.9986 | 📉 Valid Loss: 1.2780 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [459/500]
# 📉 Train Loss: 0.0110 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.3038 | 🎯 Valid Accuracy: 0.8339
#
# 📢 Epoch [460/500]
# 📉 Train Loss: 0.0096 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.1737 | 🎯 Valid Accuracy: 0.8391
#
# 📢 Epoch [461/500]
# 📉 Train Loss: 0.0041 | 🎯 Train Accuracy: 0.9985 | 📉 Valid Loss: 1.3031 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [462/500]
# 📉 Train Loss: 0.0037 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3255 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [463/500]
# 📉 Train Loss: 0.0067 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.3508 | 🎯 Valid Accuracy: 0.8207
#
# 📢 Epoch [464/500]
# 📉 Train Loss: 0.0092 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.4875 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [465/500]
# 📉 Train Loss: 0.0073 | 🎯 Train Accuracy: 0.9976 | 📉 Valid Loss: 1.4268 | 🎯 Valid Accuracy: 0.8291
#
# 📢 Epoch [466/500]
# 📉 Train Loss: 0.0050 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.3475 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [467/500]
# 📉 Train Loss: 0.0064 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3467 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [468/500]
# 📉 Train Loss: 0.0049 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.3664 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [469/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.3239 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [470/500]
# 📉 Train Loss: 0.0042 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.4286 | 🎯 Valid Accuracy: 0.8199
#
# 📢 Epoch [471/500]
# 📉 Train Loss: 0.0040 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3067 | 🎯 Valid Accuracy: 0.8431
#
# 📢 Epoch [472/500]
# 📉 Train Loss: 0.0066 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2329 | 🎯 Valid Accuracy: 0.8427
#
# 📢 Epoch [473/500]
# 📉 Train Loss: 0.0077 | 🎯 Train Accuracy: 0.9971 | 📉 Valid Loss: 1.3842 | 🎯 Valid Accuracy: 0.8343
#
# 📢 Epoch [474/500]
# 📉 Train Loss: 0.0056 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3820 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [475/500]
# 📉 Train Loss: 0.0158 | 🎯 Train Accuracy: 0.9957 | 📉 Valid Loss: 1.3086 | 🎯 Valid Accuracy: 0.8307
#
# 📢 Epoch [476/500]
# 📉 Train Loss: 0.0049 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.2749 | 🎯 Valid Accuracy: 0.8323
#
# 📢 Epoch [477/500]
# 📉 Train Loss: 0.0033 | 🎯 Train Accuracy: 0.9990 | 📉 Valid Loss: 1.4793 | 🎯 Valid Accuracy: 0.8227
#
# 📢 Epoch [478/500]
# 📉 Train Loss: 0.0011 | 🎯 Train Accuracy: 0.9995 | 📉 Valid Loss: 1.3647 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [479/500]
# 📉 Train Loss: 0.0109 | 🎯 Train Accuracy: 0.9977 | 📉 Valid Loss: 1.3719 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [480/500]
# 📉 Train Loss: 0.0052 | 🎯 Train Accuracy: 0.9981 | 📉 Valid Loss: 1.3546 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [481/500]
# 📉 Train Loss: 0.0086 | 🎯 Train Accuracy: 0.9972 | 📉 Valid Loss: 1.2571 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [482/500]
# 📉 Train Loss: 0.0053 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.3515 | 🎯 Valid Accuracy: 0.8255
#
# 📢 Epoch [483/500]
# 📉 Train Loss: 0.0061 | 🎯 Train Accuracy: 0.9982 | 📉 Valid Loss: 1.2901 | 🎯 Valid Accuracy: 0.8267
#
# 📢 Epoch [484/500]
# 📉 Train Loss: 0.0054 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.3753 | 🎯 Valid Accuracy: 0.8239
#
# 📢 Epoch [485/500]
# 📉 Train Loss: 0.0023 | 🎯 Train Accuracy: 0.9996 | 📉 Valid Loss: 1.3701 | 🎯 Valid Accuracy: 0.8295
#
# 📢 Epoch [486/500]
# 📉 Train Loss: 0.0045 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3929 | 🎯 Valid Accuracy: 0.8303
#
# 📢 Epoch [487/500]
# 📉 Train Loss: 0.0050 | 🎯 Train Accuracy: 0.9989 | 📉 Valid Loss: 1.5434 | 🎯 Valid Accuracy: 0.8227
#
# 📢 Epoch [488/500]
# 📉 Train Loss: 0.0113 | 🎯 Train Accuracy: 0.9966 | 📉 Valid Loss: 1.3303 | 🎯 Valid Accuracy: 0.8247
#
# 📢 Epoch [489/500]
# 📉 Train Loss: 0.0088 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.3152 | 🎯 Valid Accuracy: 0.8299
#
# 📢 Epoch [490/500]
# 📉 Train Loss: 0.0080 | 🎯 Train Accuracy: 0.9975 | 📉 Valid Loss: 1.3146 | 🎯 Valid Accuracy: 0.8231
#
# 📢 Epoch [491/500]
# 📉 Train Loss: 0.0029 | 🎯 Train Accuracy: 0.9992 | 📉 Valid Loss: 1.2503 | 🎯 Valid Accuracy: 0.8263
#
# 📢 Epoch [492/500]
# 📉 Train Loss: 0.0014 | 🎯 Train Accuracy: 0.9996 | 📉 Valid Loss: 1.2821 | 🎯 Valid Accuracy: 0.8363
#
# 📢 Epoch [493/500]
# 📉 Train Loss: 0.0009 | 🎯 Train Accuracy: 0.9998 | 📉 Valid Loss: 1.3049 | 🎯 Valid Accuracy: 0.8331
#
# 📢 Epoch [494/500]
# 📉 Train Loss: 0.0097 | 🎯 Train Accuracy: 0.9969 | 📉 Valid Loss: 1.3841 | 🎯 Valid Accuracy: 0.8215
#
# 📢 Epoch [495/500]
# 📉 Train Loss: 0.0128 | 🎯 Train Accuracy: 0.9955 | 📉 Valid Loss: 1.2480 | 🎯 Valid Accuracy: 0.8315
#
# 📢 Epoch [496/500]
# 📉 Train Loss: 0.0032 | 🎯 Train Accuracy: 0.9988 | 📉 Valid Loss: 1.3238 | 🎯 Valid Accuracy: 0.8255
#
# 📢 Epoch [497/500]
# 📉 Train Loss: 0.0070 | 🎯 Train Accuracy: 0.9980 | 📉 Valid Loss: 1.2885 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [498/500]
# 📉 Train Loss: 0.0036 | 🎯 Train Accuracy: 0.9987 | 📉 Valid Loss: 1.2794 | 🎯 Valid Accuracy: 0.8279
#
# 📢 Epoch [499/500]
# 📉 Train Loss: 0.0027 | 🎯 Train Accuracy: 0.9993 | 📉 Valid Loss: 1.2999 | 🎯 Valid Accuracy: 0.8255
#
# 📢 Epoch [500/500]
# 📉 Train Loss: 0.0048 | 🎯 Train Accuracy: 0.9983 | 📉 Valid Loss: 1.3356 | 🎯 Valid Accuracy: 0.8231
#
# 🔥 학습 종료! 가장 높은 검증 정확도를 기록한 에포크 🔥
# ✅ Best Epoch: 23
# 📉 Best Train Loss: 0.0802
# 🎯 Best Train Accuracy: 0.9750
# 📉 Best Valid Loss: 0.7170
# 🎯 Best Valid Accuracy: 0.8627
# 📄 학습 결과 CSV 저장됨: C:/Users/user/OneDrive/Desktop/Resnet18-real/csv\category_classification_results.csv

# %%
import os
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torchvision.models import EfficientNet_B0_Weights
import json
import pandas as pd

# ✅ GPU 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ 사용 중인 GPU:", torch.cuda.get_device_name(0))

# ✅ 경로 설정
data_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/data/category_data"
model_path = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\model\best_category_model.pth"
csv_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/csv"
test_indices_path = os.path.join(csv_dir, "test_indices.json")

# ✅ 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# ✅ 데이터셋 로드
dataset = datasets.ImageFolder(data_dir, transform=transform)

# ✅ 테스트 데이터셋 로드 (인덱스를 유지)
if os.path.exists(test_indices_path):
    with open(test_indices_path, "r") as f:
        test_indices = json.load(f)
else:
    test_size = int(0.1 * len(dataset))
    test_indices = torch.randperm(len(dataset)).tolist()[:test_size]
    with open(test_indices_path, "w") as f:
        json.dump(test_indices, f)

dataset_test = torch.utils.data.Subset(dataset, test_indices)
train_val_indices = [i for i in range(len(dataset)) if i not in test_indices]
dataset_train_val = torch.utils.data.Subset(dataset, train_val_indices)

# ✅ 학습 및 검증 데이터셋 분할
train_size = int(0.8 * len(dataset_train_val))
valid_size = len(dataset_train_val) - train_size
train_dataset, valid_dataset = random_split(dataset_train_val, [train_size, valid_size])

# ✅ 데이터 로더 준비
test_loader = DataLoader(dataset_test, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# ✅ 모델 불러오기
model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model.classifier[1] = torch.nn.Linear(model.classifier[1].in_features, len(dataset.classes))
model.load_state_dict(torch.load(model_path))
model.to(device)
model.eval()

# ✅ 평가 함수 정의
def evaluate_model(loader, dataset_name):
    correct = 0
    total = 0
    results = []
    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(loader):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predicted = outputs.argmax(1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            
            for i in range(len(labels)):
                image_idx = idx * loader.batch_size + i
                pred_label = dataset.classes[predicted[i].item()]
                true_label = dataset.classes[labels[i].item()]
                if pred_label == true_label:
                    results.append(f"[✅ 정답] 이미지 {image_idx}: 예측={pred_label}, 실제={true_label}")
                else:
                    results.append(f"[❌ 오답] 이미지 {image_idx}: 예측={pred_label}, 실제={true_label}")
    
    accuracy = correct / total
    print(f"✅ {dataset_name} 데이터셋 정확도: {accuracy:.4f}")
    for r in results[:20]:  # 상위 20개 결과 출력 (너무 많아질 수 있음)
        print(r)
    return accuracy, results

# ✅ 평가 수행
print("\n🔥 저장된 모델을 이용한 데이터셋 평가 🔥")
train_accuracy, train_results = evaluate_model(train_loader, "Train")
valid_accuracy, valid_results = evaluate_model(valid_loader, "Valid")
test_accuracy, test_results = evaluate_model(test_loader, "Test")

# # ✅ 결과 CSV 저장
# df = pd.DataFrame({
#     'Dataset': ['Train', 'Valid', 'Test'],
#     'Accuracy': [train_accuracy, valid_accuracy, test_accuracy]
# })
# csv_path = os.path.join(csv_dir, "category_classification_evaluation.csv")
# df.to_csv(csv_path, index=False)
# print(f"📄 평가 결과 CSV 저장됨: {csv_path}")

# ✅ 상세 결과 저장
detail_results_path = os.path.join(csv_dir, "detailed_classification_results2.txt")
with open(detail_results_path, "w", encoding="utf-8") as f:
    f.write("\n".join(train_results + valid_results + test_results))
print(f"📄 상세 평가 결과 저장됨: {detail_results_path}")
# Out:
# ✅ CUDA Available: True
# ✅ 사용 중인 GPU: Quadro RTX 4000
#
# 🔥 저장된 모델을 이용한 데이터셋 평가 🔥
# ✅ Train 데이터셋 정확도: 0.9555
# [✅ 정답] 이미지 0: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 1: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 2: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 3: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 4: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 5: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 6: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 7: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 8: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 9: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 10: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 11: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 12: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 13: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 14: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 15: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 16: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 17: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 18: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 19: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# ✅ Valid 데이터셋 정확도: 0.9612
# [✅ 정답] 이미지 0: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 1: 예측=전기·전자기기, 실제=전기·전자기기
# [✅ 정답] 이미지 2: 예측=랜턴, 실제=랜턴
# [✅ 정답] 이미지 3: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 4: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 5: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 6: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 7: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 8: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 9: 예측=랜턴, 실제=랜턴
# [✅ 정답] 이미지 10: 예측=텐트·타프, 실제=텐트·타프
# [❌ 오답] 이미지 11: 예측=화로대·버너, 실제=랜턴
# [✅ 정답] 이미지 12: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 13: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 14: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 15: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 16: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 17: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 18: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 19: 예측=식기·주방, 실제=식기·주방
# ✅ Test 데이터셋 정확도: 0.9539
# [✅ 정답] 이미지 0: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 1: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 2: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 3: 예측=전기·전자기기, 실제=전기·전자기기
# [✅ 정답] 이미지 4: 예측=식기·주방, 실제=식기·주방
# [❌ 오답] 이미지 5: 예측=전기·전자기기, 실제=화로대·버너
# [✅ 정답] 이미지 6: 예측=식기·주방, 실제=식기·주방
# [❌ 오답] 이미지 7: 예측=랜턴, 실제=전기·전자기기
# [✅ 정답] 이미지 8: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 9: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 10: 예측=매트·침낭, 실제=매트·침낭
# [❌ 오답] 이미지 11: 예측=냉·난방용품, 실제=매트·침낭
# [✅ 정답] 이미지 12: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 13: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 14: 예측=랜턴, 실제=랜턴
# [✅ 정답] 이미지 15: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 16: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 17: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 18: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 19: 예측=텐트·타프, 실제=텐트·타프
# 📄 상세 평가 결과 저장됨: C:/Users/user/OneDrive/Desktop/Resnet18-real/csv\detailed_classification_results2.txt

# %%
import os
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torchvision.models import EfficientNet_B0_Weights
import json
import pandas as pd

# ✅ GPU 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ 사용 중인 GPU:", torch.cuda.get_device_name(0))

# ✅ 경로 설정
data_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/data/category_data"
model_path = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\model\category_model3.pth"
csv_dir = "C:/Users/user/OneDrive/Desktop/Resnet18-real/csv"
test_indices_path = os.path.join(csv_dir, "test_indices.json")

# ✅ 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# ✅ 데이터셋 로드
dataset = datasets.ImageFolder(data_dir, transform=transform)

# ✅ 테스트 데이터셋 로드 (인덱스를 유지)
if os.path.exists(test_indices_path):
    with open(test_indices_path, "r") as f:
        test_indices = json.load(f)
else:
    test_size = int(0.1 * len(dataset))
    test_indices = torch.randperm(len(dataset)).tolist()[:test_size]
    with open(test_indices_path, "w") as f:
        json.dump(test_indices, f)

dataset_test = torch.utils.data.Subset(dataset, test_indices)
train_val_indices = [i for i in range(len(dataset)) if i not in test_indices]
dataset_train_val = torch.utils.data.Subset(dataset, train_val_indices)

# ✅ 학습 및 검증 데이터셋 분할
train_size = int(0.8 * len(dataset_train_val))
valid_size = len(dataset_train_val) - train_size
train_dataset, valid_dataset = random_split(dataset_train_val, [train_size, valid_size])

# ✅ 데이터 로더 준비
test_loader = DataLoader(dataset_test, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

# ✅ 모델 불러오기
model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)
model.classifier[1] = torch.nn.Linear(model.classifier[1].in_features, len(dataset.classes))

# ✅ 모델 가중치만 로드
checkpoint = torch.load(model_path, map_location=device)  # 🔥 저장된 체크포인트 로드
model.load_state_dict(checkpoint["model_state_dict"])  # 🔥 "model_state_dict"만 로드
model.to(device)
model.eval()

# ✅ 평가 함수 정의
def evaluate_model(loader, dataset_name):
    correct = 0
    total = 0
    results = []
    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(loader):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            predicted = outputs.argmax(1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            
            for i in range(len(labels)):
                image_idx = idx * loader.batch_size + i
                pred_label = dataset.classes[predicted[i].item()]
                true_label = dataset.classes[labels[i].item()]
                if pred_label == true_label:
                    results.append(f"[✅ 정답] 이미지 {image_idx}: 예측={pred_label}, 실제={true_label}")
                else:
                    results.append(f"[❌ 오답] 이미지 {image_idx}: 예측={pred_label}, 실제={true_label}")
    
    accuracy = correct / total
    print(f"✅ {dataset_name} 데이터셋 정확도: {accuracy:.4f}")
    for r in results[:20]:  # 상위 20개 결과 출력 (너무 많아질 수 있음)
        print(r)
    return accuracy, results

# ✅ 평가 수행
print("\n🔥 저장된 모델을 이용한 데이터셋 평가 🔥")
train_accuracy, train_results = evaluate_model(train_loader, "Train")
valid_accuracy, valid_results = evaluate_model(valid_loader, "Valid")
test_accuracy, test_results = evaluate_model(test_loader, "Test")

# # ✅ 결과 CSV 저장
# df = pd.DataFrame({
#     'Dataset': ['Train', 'Valid', 'Test'],
#     'Accuracy': [train_accuracy, valid_accuracy, test_accuracy]
# })
# csv_path = os.path.join(csv_dir, "category_classification_evaluation.csv")
# df.to_csv(csv_path, index=False)
# print(f"📄 평가 결과 CSV 저장됨: {csv_path}")

# ✅ 상세 결과 저장
detail_results_path = os.path.join(csv_dir, "detailed_classification_results2.txt")
with open(detail_results_path, "w", encoding="utf-8") as f:
    f.write("\n".join(train_results + valid_results + test_results))
print(f"📄 상세 평가 결과 저장됨: {detail_results_path}")
# Out:
# ✅ CUDA Available: True
# ✅ 사용 중인 GPU: Quadro RTX 4000
#
# 🔥 저장된 모델을 이용한 데이터셋 평가 🔥
# ✅ Train 데이터셋 정확도: 0.9738
# [✅ 정답] 이미지 0: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 1: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 2: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 3: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 4: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 5: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 6: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 7: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 8: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 9: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 10: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 11: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 12: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 13: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 14: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 15: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 16: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 17: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 18: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 19: 예측=식기·주방, 실제=식기·주방
# ✅ Valid 데이터셋 정확도: 0.9728
# [✅ 정답] 이미지 0: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 1: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 2: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 3: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 4: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 5: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 6: 예측=전기·전자기기, 실제=전기·전자기기
# [✅ 정답] 이미지 7: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 8: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 9: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 10: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 11: 예측=텐트·타프, 실제=텐트·타프
# [✅ 정답] 이미지 12: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 13: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 14: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 15: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 16: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 17: 예측=가방·박스·웨건, 실제=가방·박스·웨건
# [✅ 정답] 이미지 18: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 19: 예측=매트·침낭, 실제=매트·침낭
# ✅ Test 데이터셋 정확도: 0.9748
# [✅ 정답] 이미지 0: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 1: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 2: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 3: 예측=전기·전자기기, 실제=전기·전자기기
# [✅ 정답] 이미지 4: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 5: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 6: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 7: 예측=전기·전자기기, 실제=전기·전자기기
# [✅ 정답] 이미지 8: 예측=식기·주방, 실제=식기·주방
# [✅ 정답] 이미지 9: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 10: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 11: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 12: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 13: 예측=화로대·버너, 실제=화로대·버너
# [✅ 정답] 이미지 14: 예측=랜턴, 실제=랜턴
# [✅ 정답] 이미지 15: 예측=매트·침낭, 실제=매트·침낭
# [✅ 정답] 이미지 16: 예측=공구·액세서리, 실제=공구·액세서리
# [✅ 정답] 이미지 17: 예측=냉·난방용품, 실제=냉·난방용품
# [✅ 정답] 이미지 18: 예측=테이블·체어, 실제=테이블·체어
# [✅ 정답] 이미지 19: 예측=텐트·타프, 실제=텐트·타프
# 📄 상세 평가 결과 저장됨: C:/Users/user/OneDrive/Desktop/Resnet18-real/csv\detailed_classification_results2.txt
