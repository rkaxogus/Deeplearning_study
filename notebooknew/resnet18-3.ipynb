# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
from torch.utils.data import DataLoader, Subset  # [변경됨]: random_split 대신 Subset 사용
import json
import pandas as pd
import numpy as np  # [변경됨]: numpy 임포트

# [추가됨] 재현성을 위한 시드 설정
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 데이터 경로 설정
data_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\data\brand_data3"
processed_data_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\data\processed_data3"
json_save_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\json"
csv_save_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\csv"
model_save_path = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\modelnew\resnet18-3.pth"

# JSON, CSV 저장 폴더 생성
os.makedirs(json_save_dir, exist_ok=True)
os.makedirs(csv_save_dir, exist_ok=True)

# 모든 브랜드 폴더를 순회하면서 하위 제품 폴더 이동
for brand in os.listdir(data_dir):
    brand_path = os.path.join(data_dir, brand)
    if os.path.isdir(brand_path):
        for product in os.listdir(brand_path):
            product_path = os.path.join(brand_path, product)
            if os.path.isdir(product_path):
                new_product_path = os.path.join(processed_data_dir, product)
                os.makedirs(new_product_path, exist_ok=True)
                for image in os.listdir(product_path):
                    src = os.path.join(product_path, image)
                    dst = os.path.join(new_product_path, image)
                    shutil.copy(src, dst)

print("✅ 모든 제품 폴더를 'processed_data3'로 이동 완료!")

# 이미지 변환 설정
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 데이터셋 로드
dataset = datasets.ImageFolder(root=processed_data_dir, transform=transform)
num_classes = len(dataset.classes)
print(f"총 클래스 개수: {num_classes}")
print("클래스 목록:", dataset.classes)

# [변경됨] 데이터셋 분할 - 클래스별로 7:2:1 비율로 분할
# 각 클래스별 인덱스 추출
class_indices = {cls: [] for cls in range(num_classes)}
for idx, (path, label) in enumerate(dataset.imgs):
    class_indices[label].append(idx)

train_indices, val_indices, test_indices = [], [], []
for label, indices in class_indices.items():
    np.random.shuffle(indices)  # 인덱스 랜덤 셔플
    n = len(indices)
    n_train = int(0.7 * n)
    n_val = int(0.2 * n)
    # 나머지는 테스트셋에 할당
    train_indices.extend(indices[:n_train])
    val_indices.extend(indices[n_train:n_train+n_val])
    test_indices.extend(indices[n_train+n_val:])

train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)
# [변경됨 끝]

# JSON 파일로 데이터셋 저장
def save_json(subset_dataset, dataset_name):
    data_list = [{"image_path": subset_dataset.dataset.imgs[i][0], "label": int(subset_dataset.dataset.imgs[i][1])} 
                for i in subset_dataset.indices]
    json_path = os.path.join(json_save_dir, f"{dataset_name}.json")
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(data_list, f, indent=4)
    print(f"✅ {dataset_name}.json 저장 완료!")

save_json(train_dataset, "train3")
save_json(val_dataset, "val3")
save_json(test_dataset, "test3")

# 데이터 로더 설정
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

print("✅ 데이터 로더 생성 완료!")

# 모델 설정 (ResNet18)
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# 손실 함수 및 최적화 함수 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)

# [추가됨] Learning rate scheduler (ReduceLROnPlateau 사용 - 검증 정확도를 기준으로 학습률 조절)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10, verbose=True)

# 학습 기록 저장용 DataFrame
history = {"epoch": [], "train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

# [추가됨] Early Stopping 설정 변수 (개선이 없을 시 조기 종료)
early_stop_patience = 20
no_improve_count = 0

# [추가됨] 로그 파일 생성 (학습 기록 추가 저장)
log_file = os.path.join(csv_save_dir, "train_log3.txt")
with open(log_file, "w") as lf:
    lf.write("Epoch,Train Loss,Train Acc,Val Loss,Val Acc,Learning Rate\n")

# 모델 학습 함수
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20):
    global no_improve_count  # [추가됨] early stopping 카운트 변수 사용
    best_acc = 0.0

    for epoch in range(num_epochs):
        model.train()
        train_loss, correct_train, total_train = 0.0, 0, 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            correct_train += predicted.eq(labels).sum().item()
            total_train += labels.size(0)

        train_acc = 100 * correct_train / total_train
        train_loss /= len(train_loader)

        model.eval()
        val_loss, correct_val, total_val = 0.0, 0, 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                correct_val += predicted.eq(labels).sum().item()
                total_val += labels.size(0)

        val_acc = 100 * correct_val / total_val
        val_loss /= len(val_loader)

        history["epoch"].append(epoch + 1)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f"🚀 Epoch [{epoch+1}/{num_epochs}] | 📉 Train Loss: {train_loss:.4f} | 🎯 Train Accuracy: {train_acc:.4f} | 📑 Valid Loss: {val_loss:.4f} | 🎯 Valid Accuracy: {val_acc:.4f}")

        # [추가됨] Learning rate scheduler step (검증 정확도를 기준으로 학습률 조정)
        scheduler.step(val_acc)
        current_lr = optimizer.param_groups[0]['lr']
        print(f"현재 학습률: {current_lr:.6f}")

        # [추가됨] 로그 파일에 학습 기록 추가 저장
        with open(log_file, "a") as lf:
            lf.write(f"{epoch+1},{train_loss:.4f},{train_acc:.4f},{val_loss:.4f},{val_acc:.4f},{current_lr:.6f}\n")

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), model_save_path)
            print(f"📌 새로운 최고 모델 저장됨! (Epoch {epoch+1}, Accuracy: {val_acc:.4f}) ✅")
            no_improve_count = 0  # [추가됨] 개선되었으므로 카운트 초기화
        else:
            no_improve_count += 1  # [추가됨] 개선되지 않음

        # [추가됨] Early Stopping 조건 확인 (개선이 없으면 조기 종료)
        if no_improve_count >= early_stop_patience:
            print(f"🚨 조기 종료: {early_stop_patience} 에폭 동안 개선 없음.")
            break

    print(f"🎯 최종 최고 검증 정확도: {best_acc:.2f}%")

# 모델 학습 실행
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=500)

# 학습 과정 CSV로 저장
df = pd.DataFrame(history)
csv_path = os.path.join(csv_save_dir, "텐트분류3.csv")
df.to_csv(csv_path, index=False)
print(f"✅ 학습 기록 저장 완료: {csv_path}")

# 최적 모델 로드 후 테스트 데이터 평가
model.load_state_dict(torch.load(model_save_path))
model.eval()
correct_test, total_test = 0, 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        correct_test += predicted.eq(labels).sum().item()
        total_test += labels.size(0)

test_acc = 100 * correct_test / total_test
print(f"🎯 테스트 데이터셋 정확도: {test_acc:.2f}%")
# Out:
# Using device: cuda
# ✅ 모든 제품 폴더를 'processed_data3'로 이동 완료!
# 총 클래스 개수: 57
# 클래스 목록: ['12X', '4S 와이드', '6.3', 'A5', 'A7', 'IE', 'P1', 'X5', '가마보코', '날로', '노나돔', '니악', '도크돔', '라이더스', '랜드록', '랜드브리즈', '레이사', '리빙쉘', '문라이트', '미라클패밀리', '바랑에르돔', '발할', '뱅가드', '브이타프', '비무르', '비바돔', '빌리지', '새턴 쉘터', '새턴2룸', '솔로', '쉘터G', '스텔라릿지', '아고라', '아스가르드', '아퀼라', '아틀라스', '아티카', '알베르게', '알파인돔', '알페임', '어메니티돔', '오토듀얼팔레스', '와가야노', '우나', '우트가르드', '웨더마스터', '인디아나', '인스턴트업 3p', '캥거루', '코트텐트', '크로노스', '클라우드업', '투어링돔', '파프리카', '패스빅', '퍼시픽오션', '필드터널']
# ✅ train3.json 저장 완료!
# ✅ val3.json 저장 완료!
# ✅ test3.json 저장 완료!
# ✅ 데이터 로더 생성 완료!
# c:\Users\user\anaconda3\envs\classification3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\user\anaconda3\envs\classification3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 🚀 Epoch [1/500] | 📉 Train Loss: 2.0249 | 🎯 Train Accuracy: 53.3275 | 📑 Valid Loss: 1.1204 | 🎯 Valid Accuracy: 73.0817
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 1, Accuracy: 73.0817) ✅
# 🚀 Epoch [2/500] | 📉 Train Loss: 0.8241 | 🎯 Train Accuracy: 81.3835 | 📑 Valid Loss: 0.7782 | 🎯 Valid Accuracy: 79.5173
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 2, Accuracy: 79.5173) ✅
# 🚀 Epoch [3/500] | 📉 Train Loss: 0.5300 | 🎯 Train Accuracy: 87.6007 | 📑 Valid Loss: 0.6662 | 🎯 Valid Accuracy: 82.2401
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 3, Accuracy: 82.2401) ✅
# 🚀 Epoch [4/500] | 📉 Train Loss: 0.3761 | 🎯 Train Accuracy: 90.5429 | 📑 Valid Loss: 0.6715 | 🎯 Valid Accuracy: 82.3639
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 4, Accuracy: 82.3639) ✅
# 🚀 Epoch [5/500] | 📉 Train Loss: 0.3049 | 🎯 Train Accuracy: 91.9089 | 📑 Valid Loss: 0.6534 | 🎯 Valid Accuracy: 83.2302
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 5, Accuracy: 83.2302) ✅
# 🚀 Epoch [6/500] | 📉 Train Loss: 0.2564 | 🎯 Train Accuracy: 93.0648 | 📑 Valid Loss: 0.6412 | 🎯 Valid Accuracy: 82.6114
# 현재 학습률: 0.000100
# 🚀 Epoch [7/500] | 📉 Train Loss: 0.2287 | 🎯 Train Accuracy: 93.5201 | 📑 Valid Loss: 0.7111 | 🎯 Valid Accuracy: 81.6832
# 현재 학습률: 0.000100
# 🚀 Epoch [8/500] | 📉 Train Loss: 0.2105 | 🎯 Train Accuracy: 93.6077 | 📑 Valid Loss: 0.6253 | 🎯 Valid Accuracy: 83.2921
# 현재 학습률: 0.000100
# 📌 새로운 최고 모델 저장됨! (Epoch 8, Accuracy: 83.2921) ✅
# 🚀 Epoch [9/500] | 📉 Train Loss: 0.1938 | 🎯 Train Accuracy: 94.0630 | 📑 Valid Loss: 0.6561 | 🎯 Valid Accuracy: 82.9827
# 현재 학습률: 0.000100
# 🚀 Epoch [10/500] | 📉 Train Loss: 0.1784 | 🎯 Train Accuracy: 94.1856 | 📑 Valid Loss: 0.6634 | 🎯 Valid Accuracy: 83.2921
# 현재 학습률: 0.000100
# 🚀 Epoch [11/500] | 📉 Train Loss: 0.1692 | 🎯 Train Accuracy: 94.2207 | 📑 Valid Loss: 0.7186 | 🎯 Valid Accuracy: 81.1262
# 현재 학습률: 0.000100
# 🚀 Epoch [12/500] | 📉 Train Loss: 0.1684 | 🎯 Train Accuracy: 94.1156 | 📑 Valid Loss: 0.6701 | 🎯 Valid Accuracy: 83.2921
# 현재 학습률: 0.000100
# 🚀 Epoch [13/500] | 📉 Train Loss: 0.1533 | 🎯 Train Accuracy: 94.6760 | 📑 Valid Loss: 0.6705 | 🎯 Valid Accuracy: 82.8589
# 현재 학습률: 0.000100
# 🚀 Epoch [14/500] | 📉 Train Loss: 0.1580 | 🎯 Train Accuracy: 94.5009 | 📑 Valid Loss: 0.7161 | 🎯 Valid Accuracy: 81.9926
# 현재 학습률: 0.000100
# 🚀 Epoch [15/500] | 📉 Train Loss: 0.1510 | 🎯 Train Accuracy: 94.3433 | 📑 Valid Loss: 0.6905 | 🎯 Valid Accuracy: 82.3639
# 현재 학습률: 0.000100
# 🚀 Epoch [16/500] | 📉 Train Loss: 0.1503 | 🎯 Train Accuracy: 94.6410 | 📑 Valid Loss: 0.7064 | 🎯 Valid Accuracy: 82.9827
# 현재 학습률: 0.000100
# 🚀 Epoch [17/500] | 📉 Train Loss: 0.1458 | 🎯 Train Accuracy: 94.3958 | 📑 Valid Loss: 0.7236 | 🎯 Valid Accuracy: 82.4257
# 현재 학습률: 0.000100
# 🚀 Epoch [18/500] | 📉 Train Loss: 0.1400 | 🎯 Train Accuracy: 94.4133 | 📑 Valid Loss: 0.7017 | 🎯 Valid Accuracy: 82.5495
# 현재 학습률: 0.000100
# 🚀 Epoch [19/500] | 📉 Train Loss: 0.1362 | 🎯 Train Accuracy: 94.8161 | 📑 Valid Loss: 0.7433 | 🎯 Valid Accuracy: 81.0644
# Epoch 00019: reducing learning rate of group 0 to 5.0000e-05.
# 현재 학습률: 0.000050
# 🚀 Epoch [20/500] | 📉 Train Loss: 0.1147 | 🎯 Train Accuracy: 95.1138 | 📑 Valid Loss: 0.7363 | 🎯 Valid Accuracy: 82.1782
# 현재 학습률: 0.000050
# 🚀 Epoch [21/500] | 📉 Train Loss: 0.1018 | 🎯 Train Accuracy: 95.4291 | 📑 Valid Loss: 0.7471 | 🎯 Valid Accuracy: 82.6733
# 현재 학습률: 0.000050
# 🚀 Epoch [22/500] | 📉 Train Loss: 0.0992 | 🎯 Train Accuracy: 95.3240 | 📑 Valid Loss: 0.7140 | 🎯 Valid Accuracy: 83.9728
# 현재 학습률: 0.000050
# 📌 새로운 최고 모델 저장됨! (Epoch 22, Accuracy: 83.9728) ✅
# 🚀 Epoch [23/500] | 📉 Train Loss: 0.0965 | 🎯 Train Accuracy: 95.3765 | 📑 Valid Loss: 0.7392 | 🎯 Valid Accuracy: 82.7351
# 현재 학습률: 0.000050
# 🚀 Epoch [24/500] | 📉 Train Loss: 0.0959 | 🎯 Train Accuracy: 95.5342 | 📑 Valid Loss: 0.7408 | 🎯 Valid Accuracy: 83.2302
# 현재 학습률: 0.000050
# 🚀 Epoch [25/500] | 📉 Train Loss: 0.0940 | 🎯 Train Accuracy: 95.1489 | 📑 Valid Loss: 0.7848 | 🎯 Valid Accuracy: 81.6832
# 현재 학습률: 0.000050
# 🚀 Epoch [26/500] | 📉 Train Loss: 0.0933 | 🎯 Train Accuracy: 95.5692 | 📑 Valid Loss: 0.7769 | 🎯 Valid Accuracy: 82.8589
# 현재 학습률: 0.000050
# 🚀 Epoch [27/500] | 📉 Train Loss: 0.0972 | 🎯 Train Accuracy: 95.0963 | 📑 Valid Loss: 0.7827 | 🎯 Valid Accuracy: 82.8589
# 현재 학습률: 0.000050
# 🚀 Epoch [28/500] | 📉 Train Loss: 0.0946 | 🎯 Train Accuracy: 95.4991 | 📑 Valid Loss: 0.7796 | 🎯 Valid Accuracy: 83.0446
# 현재 학습률: 0.000050
# 🚀 Epoch [29/500] | 📉 Train Loss: 0.0942 | 🎯 Train Accuracy: 95.2189 | 📑 Valid Loss: 0.7831 | 🎯 Valid Accuracy: 82.3639
# 현재 학습률: 0.000050
# 🚀 Epoch [30/500] | 📉 Train Loss: 0.0912 | 🎯 Train Accuracy: 95.3940 | 📑 Valid Loss: 0.7964 | 🎯 Valid Accuracy: 82.3020
# 현재 학습률: 0.000050
# 🚀 Epoch [31/500] | 📉 Train Loss: 0.0904 | 🎯 Train Accuracy: 95.3940 | 📑 Valid Loss: 0.8021 | 🎯 Valid Accuracy: 81.9926
# 현재 학습률: 0.000050
# 🚀 Epoch [32/500] | 📉 Train Loss: 0.0880 | 🎯 Train Accuracy: 95.6918 | 📑 Valid Loss: 0.8100 | 🎯 Valid Accuracy: 82.3020
# 현재 학습률: 0.000050
# 🚀 Epoch [33/500] | 📉 Train Loss: 0.0894 | 🎯 Train Accuracy: 95.6042 | 📑 Valid Loss: 0.8437 | 🎯 Valid Accuracy: 81.5594
# Epoch 00033: reducing learning rate of group 0 to 2.5000e-05.
# 현재 학습률: 0.000025
# 🚀 Epoch [34/500] | 📉 Train Loss: 0.0810 | 🎯 Train Accuracy: 95.6042 | 📑 Valid Loss: 0.8038 | 🎯 Valid Accuracy: 82.1782
# 현재 학습률: 0.000025
# 🚀 Epoch [35/500] | 📉 Train Loss: 0.0767 | 🎯 Train Accuracy: 95.7443 | 📑 Valid Loss: 0.8262 | 🎯 Valid Accuracy: 82.3639
# 현재 학습률: 0.000025
# 🚀 Epoch [36/500] | 📉 Train Loss: 0.0730 | 🎯 Train Accuracy: 96.0245 | 📑 Valid Loss: 0.8404 | 🎯 Valid Accuracy: 82.3020
# 현재 학습률: 0.000025
# 🚀 Epoch [37/500] | 📉 Train Loss: 0.0745 | 🎯 Train Accuracy: 95.8144 | 📑 Valid Loss: 0.8079 | 🎯 Valid Accuracy: 82.6733
# 현재 학습률: 0.000025
# 🚀 Epoch [38/500] | 📉 Train Loss: 0.0767 | 🎯 Train Accuracy: 95.6918 | 📑 Valid Loss: 0.8477 | 🎯 Valid Accuracy: 82.4257
# 현재 학습률: 0.000025
# 🚀 Epoch [39/500] | 📉 Train Loss: 0.0731 | 🎯 Train Accuracy: 95.9194 | 📑 Valid Loss: 0.8239 | 🎯 Valid Accuracy: 82.8589
# 현재 학습률: 0.000025
# 🚀 Epoch [40/500] | 📉 Train Loss: 0.0771 | 🎯 Train Accuracy: 95.7618 | 📑 Valid Loss: 0.8457 | 🎯 Valid Accuracy: 82.2401
# 현재 학습률: 0.000025
# 🚀 Epoch [41/500] | 📉 Train Loss: 0.0745 | 🎯 Train Accuracy: 95.8319 | 📑 Valid Loss: 0.8600 | 🎯 Valid Accuracy: 82.3020
# 현재 학습률: 0.000025
# 🚀 Epoch [42/500] | 📉 Train Loss: 0.0733 | 🎯 Train Accuracy: 95.6567 | 📑 Valid Loss: 0.8393 | 🎯 Valid Accuracy: 82.3639
# 현재 학습률: 0.000025
# 🚨 조기 종료: 20 에폭 동안 개선 없음.
# 🎯 최종 최고 검증 정확도: 83.97%
# ✅ 학습 기록 저장 완료: C:\Users\user\OneDrive\Desktop\Resnet18-real\csv\텐트분류3.csv
# 🎯 테스트 데이터셋 정확도: 81.31%

# %%
import os
import json
import torch
import torchvision.transforms as transforms
from PIL import Image
import torchvision.models as models
import torch.nn as nn
import torchvision.datasets as datasets
import csv

# 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 경로 설정
processed_data_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\data\processed_data3"
json_save_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\json"
model_save_path = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\modelnew\resnet18-3.pth"

# 평가용 이미지 전처리 (augmentation은 제거)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# ImageFolder를 통해 클래스 정보를 불러옴
dummy_dataset = datasets.ImageFolder(root=processed_data_dir, transform=transform)
num_classes = len(dummy_dataset.classes)
class_names = dummy_dataset.classes
print(f"총 클래스 개수: {num_classes}")
print("클래스 목록:", class_names)

# 모델 구성 (ResNet18) 및 가중치 로드
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.load_state_dict(torch.load(model_save_path, map_location=device))
model = model.to(device)
model.eval()
print("모델 로드 완료!")

def evaluate_json_dataset(json_path, dataset_name):
    """
    주어진 json 파일을 불러와서 각 이미지에 대해 예측 수행합니다.
    이미지별 정답/오답 여부(예측값과 정답)를 출력하고,
    마지막에 전체 정확도 및 클래스별 정확도를 출력합니다.
    """
    with open(json_path, "r", encoding="utf-8") as f:
        data_list = json.load(f)
    
    total = len(data_list)
    correct = 0
    
    # 클래스별 정답/전체 카운터 초기화
    correct_by_class = {i: 0 for i in range(num_classes)}
    total_by_class = {i: 0 for i in range(num_classes)}
    
    print(f"\n===== {dataset_name.upper()} 데이터셋 평가 시작 (총 {total}개 이미지) =====")
    
    for sample in data_list:
        image_path = sample["image_path"]
        true_label = sample["label"]
        total_by_class[true_label] += 1
        
        # 이미지 로드 및 전처리
        try:
            image = Image.open(image_path).convert("RGB")
        except Exception as e:
            print(f"이미지 로드 실패: {image_path} ({e})")
            continue
        input_tensor = transform(image).unsqueeze(0).to(device)
        
        # 예측 수행
        with torch.no_grad():
            output = model(input_tensor)
            _, pred_label = torch.max(output, 1)
            pred_label = pred_label.item()
        
        # 정답/오답 여부 판단
        if pred_label == true_label:
            correct += 1
            correct_by_class[true_label] += 1
            result = "✅ 정답"
        else:
            result = f"❌ 오답 (예측: {pred_label}, 정답: {true_label})"
        
        print(f"{os.path.basename(image_path)} -> {result}")
    
    overall_acc = 100 * correct / total if total > 0 else 0
    print(f"\n===== {dataset_name.upper()} 데이터셋 전체 정확도: {correct} / {total} = {overall_acc:.2f}% =====")
    
    print(f"----- {dataset_name.upper()} 데이터셋 클래스별 정확도 -----")
    for cls in range(num_classes):
        cls_total = total_by_class[cls]
        cls_correct = correct_by_class[cls]
        if cls_total > 0:
            cls_acc = 100 * cls_correct / cls_total
        else:
            cls_acc = 0
        print(f"[{class_names[cls]}] : {cls_correct} / {cls_total} = {cls_acc:.2f}%")
    
    print("======================================================\n")
    
    # 전체 정확도, 클래스별 정답/전체를 반환
    return overall_acc, correct_by_class, total_by_class

# JSON 파일 경로 설정 및 평가 실행
results = {}
for ds in ["train3", "val3", "test3"]:
    json_path = os.path.join(json_save_dir, f"{ds}.json")
    if os.path.exists(json_path):
        print(f"== {ds.upper()} 데이터셋 평가 ==")
        # evaluate_json_dataset 함수가 (overall_acc, correct_by_class, total_by_class)를 반환
        results[ds] = evaluate_json_dataset(json_path, ds)
    else:
        print(f"{ds}.json 파일을 찾을 수 없습니다.")

# ===== 최종 요약 출력 (train, val, test 정확도) =====
print("===== 전체 요약 =====")
for ds in ["train3", "val3", "test3"]:
    if ds in results:
        overall_acc, _, _ = results[ds]
        print(f"{ds.upper()} 데이터셋 최종 정확도: {overall_acc:.2f}%")

# ===== CSV 파일로 저장 =====
# 저장 경로 및 파일명 설정
csv_save_dir = r"C:\Users\user\OneDrive\Desktop\Resnet18-real\csv"
os.makedirs(csv_save_dir, exist_ok=True)  # 폴더가 없으면 생성
csv_file_path = os.path.join(csv_save_dir, "모델정확도.csv")

with open(csv_file_path, 'w', newline='', encoding='utf-8-sig') as csvfile:
    writer = csv.writer(csvfile)
    # 헤더 작성: Dataset, Type(Overall 또는 클래스), Correct, Total, Accuracy (%)
    writer.writerow(["Dataset", "Type", "Correct", "Total", "Accuracy (%)"])
    for ds, (overall_acc, correct_by_class, total_by_class) in results.items():
        total_dataset = sum(total_by_class.values())
        total_correct = sum(correct_by_class.values())
        # Overall 결과
        writer.writerow([ds, "Overall", total_correct, total_dataset, f"{overall_acc:.2f}"])
        # 클래스별 결과
        for cls in range(num_classes):
            cls_total = total_by_class[cls]
            cls_correct = correct_by_class[cls]
            cls_acc = 100 * cls_correct / cls_total if cls_total > 0 else 0
            writer.writerow([ds, class_names[cls], cls_correct, cls_total, f"{cls_acc:.2f}"])

print(f"CSV 파일이 저장되었습니다: {csv_file_path}")
# Out:
# Using device: cuda
# 총 클래스 개수: 57
# 클래스 목록: ['12X', '4S 와이드', '6.3', 'A5', 'A7', 'IE', 'P1', 'X5', '가마보코', '날로', '노나돔', '니악', '도크돔', '라이더스', '랜드록', '랜드브리즈', '레이사', '리빙쉘', '문라이트', '미라클패밀리', '바랑에르돔', '발할', '뱅가드', '브이타프', '비무르', '비바돔', '빌리지', '새턴 쉘터', '새턴2룸', '솔로', '쉘터G', '스텔라릿지', '아고라', '아스가르드', '아퀼라', '아틀라스', '아티카', '알베르게', '알파인돔', '알페임', '어메니티돔', '오토듀얼팔레스', '와가야노', '우나', '우트가르드', '웨더마스터', '인디아나', '인스턴트업 3p', '캥거루', '코트텐트', '크로노스', '클라우드업', '투어링돔', '파프리카', '패스빅', '퍼시픽오션', '필드터널']
# 모델 로드 완료!
# == TRAIN3 데이터셋 평가 ==
#
# ===== TRAIN3 데이터셋 평가 시작 (총 5710개 이미지) =====
# 1663482870117000ccq_L7Cxg.jpg -> ✅ 정답
# IMG_0887.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_18_1.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_44.jpg -> ✅ 정답
# google_NatureHike 12X tent_33.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_7_2.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_128_1.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_51.jpg -> ✅ 정답
# google_NatureHike 12X tent_30.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_84.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_47.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_57.jpg -> ✅ 정답
# maxresdefault.jpg -> ✅ 정답
# 3d312b4f76c085b2caadddd9ba287714.webp -> ✅ 정답
# naver_네이처하이크 12X 텐트_69.jpg -> ✅ 정답
# google_NatureHike 12X tent_72.jpg -> ✅ 정답
# google_NatureHike 12X tent_23_1.jpg -> ✅ 정답
# google_NatureHike 12X tent_12.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_24.jpg -> ✅ 정답
# D8SrJ3kvTV2u4SPjU0dibw.jpeg -> ✅ 정답
# naver_네이처하이크 12X 텐트_40.jpg -> ✅ 정답
# google_NatureHike 12X tent_9.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_133_2.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_85_1.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_6_1.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_80.jpg -> ✅ 정답
# google_NatureHike 12X tent_46.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_72.jpg -> ✅ 정답
# google_NatureHike 12X tent_24_1.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_86.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_71.jpg -> ✅ 정답
# google_NatureHike 12X tent_66.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_19.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_8.jpg -> ✅ 정답
# google_NatureHike 12X tent_28.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_11.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_79.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_24_1.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_19_1.jpg -> ✅ 정답
# google_네이처하이크 12X 텐트_78.jpg -> ✅ 정답
# naver_네이처하이크 12X 텐트_41.jpg -> ✅ 정답
# 1693738000100_000_wGw8w_main.jpeg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_145.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_194.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_21.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_320.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_236.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_139.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_156.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_306.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_56.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_69.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_362.jpg -> ❌ 오답 (예측: 45, 정답: 1)
# naver_콜맨 4S 와이드 텐트_178.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_307.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_31.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_203.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_14.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_24.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_78.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_369.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_278.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_370.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_72.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_151.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_168.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_123.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_73.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_291.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_142.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_26.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_384.jpg -> ❌ 오답 (예측: 45, 정답: 1)
# naver_콜맨 4S 와이드 텐트_47.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_271.jpg -> ❌ 오답 (예측: 45, 정답: 1)
# naver_콜맨 4S 와이드 텐트_357.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_79.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_304.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_167.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_62.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_300.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_305.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_17.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_131.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_193.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_77.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_378.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_345.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_332.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_35.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_180.jpg -> ❌ 오답 (예측: 45, 정답: 1)
# naver_콜맨 4S 와이드 텐트_6.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트_59.jpg -> ✅ 정답
# naver_콜맨 4S 와이드 텐트
# naver_DOD IE 텐트_148.jpg -> ✅ 정답
# google_DOD IE 텐트_43.jpg -> ✅ 정답
# naver_DOD IE 텐트_220.jpg -> ❌ 오답 (예측: 42, 정답: 5)
# google_DOD IE 텐트_25.jpg -> ✅ 정답
# google_DOD IE 텐트_16.jpg -> ✅ 정답
# google_DOD IE 텐트_7.jpg -> ✅ 정답
# naver_DOD IE 텐트_243.jpg -> ❌ 오답 (예측: 42, 정답: 5)
# naver_DOD IE 텐트_327.jpg -> ✅ 정답
# naver_DOD IE 텐트_163.jpg -> ✅ 정답
# size__780_780 (1).webp -> ✅ 정답
# t3_022_tn_top_band_08.jpg -> ✅ 정답
# naver_DOD IE 텐트_292.jpg -> ✅ 정답
# naver_DOD IE 텐트_196.jpg -> ✅ 정답
# google_DOD IE 텐트_47.jpg -> ✅ 정답
# naver_DOD IE 텐트_273.jpg -> ❌ 오답 (예측: 42, 정답: 5)
# google_DOD IE 텐트_71.jpg -> ✅ 정답
# naver_DOD IE 텐트_123.jpg -> ❌ 오답 (예측: 42, 정답: 5)
# google_DOD IE 텐트_17.jpg -> ✅ 정답
# naver_DOD IE 텐트_290.jpg -> ❌ 오답 (예측: 42, 정답: 5)
# naver_DOD IE 텐트_204.jpg -> ❌ 오답 (예측: 48, 정답: 5)
# naver_DOD IE 텐트_259.jpg -> ✅ 정답
# naver_DOD IE 텐트_205.jpg -> ✅ 정답
# naver_DOD IE 텐트_82.jpg -> ✅ 정답
# google_DOD IE 텐트_49.jpg -> ✅ 정답
# google_DOD IE tent_76.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_27.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_15.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_31.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_56.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_166.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_3.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_51.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_282.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_10.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_16.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_54.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_46.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_45.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_23.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_248.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_36.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_395.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_184.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_5.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_44.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_80.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_156.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_396.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_43.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_4.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_152.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_349.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_266.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_40.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_308.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_119.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_132.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_236.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_150.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_48.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_8.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_298.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_81.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_138.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_97.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_228.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_77.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_391.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_34.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_87.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_38.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_93.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_123.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_246.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_14.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_148.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_235.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_26.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_181.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_347.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_232.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_106.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_249.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_41.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_182.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_265.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_155.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_238.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_272.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_279.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_275.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_101.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_1.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_7.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_351.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_145.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_64.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_52.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_82.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_297.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_348.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_354.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_72.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_99.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_254.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_274.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_143.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_170.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_30.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_203.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_102.jpg -> ✅ 정답
# naver_폴라리스 P1 텐트_233.jpg -> ✅ 정답
# google_카즈미 X5 텐트_37.jpg -> ✅ 정답
# google_카즈미 X5 텐트_2.jpg -> ✅ 정답
# google_카즈미 X5 텐트_89.jpg -> ✅ 정답
# google_Kazmi X5 tent_63.jpg -> ✅ 정답
# google_카즈미 X5 텐트_12.jpg -> ✅ 정답
# google_Kazmi X5 tent_64.jpg -> ✅ 정답
# google_카즈미 X5 텐트_62.jpg -> ✅ 정답
# google_Kazmi X5 tent_79.jpg -> ❌ 오답 (예측: 36, 정답: 7)
# google_카즈미 X5 텐트_91.jpg -> ❌ 오답 (예측: 22, 정답: 7)
# google_카즈미 X5 텐트_55.jpg -> ✅ 정답
# google_카즈미 X5 텐트_51.jpg -> ✅ 정답
# google_카즈미 X5 텐트_79.jpg -> ✅ 정답
jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_12.jpg -> ✅ 정답
# google_Hilleberg Niak tent_23.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_388.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_329.jpg -> ✅ 정답
# google_Hilleberg Niak tent_60.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_166_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_213_1.jpg -> ❌ 오답 (예측: 43, 정답: 11)
# naver_힐레베르그 니악 텐트_64.jpg -> ✅ 정답
# google_Hilleberg Niak tent_147.jpg -> ✅ 정답
# google_Hilleberg Niak tent_155.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_208_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_182.jpg -> ✅ 정답
# google_Hilleberg Niak tent_9.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_393.jpg -> ✅ 정답
# google_Hilleberg Niak tent_164.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_113_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_371_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_188_1.jpg -> ❌ 오답 (예측: 9, 정답: 11)
# naver_힐레베르그 니악 텐트_164.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_188.jpg -> ✅ 정답
# google_Hilleberg Niak tent_73.jpg -> ✅ 정답
# google_Hilleberg Niak tent_48.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_248.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_189_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_82_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_18_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_168.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_21_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_77.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_251_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# google_Hilleberg Niak tent_99.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_358_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_35.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_116.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_227.jpg -> ✅ 정답
# google_Hilleberg Niak tent_2.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_228.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_300.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_220_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_203.jpg -> ✅ 정답
# google_Hilleberg Niak tent_200.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_115.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_177.jpg -> ✅ 정답
# google_Hilleberg Niak tent_22.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_112.jpg -> ✅ 정답
# google_Hilleberg Niak tent_16.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_163.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_199.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_322_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_96.jpg -> ✅ 정답
# google_Hilleberg Niak tent_68.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_253.jpg -> ✅ 정답
# google_Hilleberg Niak tent_135.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_293_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_29.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_16.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_366.jpg -> ❌ 오답 (예측: 29, 정답: 11)
# naver_힐레베르그 니악 텐트_198.jpg -> ✅ 정답
# google_Hilleberg Niak tent_180.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_269_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_362.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# google_Hilleberg Niak tent_140.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_232_1.jpg -> ❌ 오답 (예측: 29, 정답: 11)
# naver_힐레베르그 니악 텐트_124.jpg -> ✅ 정답
# google_Hilleberg Niak tent_42.jpg -> ✅ 정답
# google_Hilleberg Niak tent_190.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_190_1.jpg -> ❌ 오답 (예측: 29, 정답: 11)
# naver_힐레베르그 니악 텐트_292_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_148.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_184.jpg -> ✅ 정답
# google_Hilleberg Niak tent_119.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_270.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_153.jpg -> ✅ 정답
# google_Hilleberg Niak tent_30.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_76.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_206_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# google_Hilleberg Niak tent_106.jpg -> ✅ 정답
# google_Hilleberg Niak tent_110.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_295_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_3_1.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# naver_힐레베르그 니악 텐트_200.jpg -> ✅ 정답
# google_Hilleberg Niak tent_21.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_162.jpg -> ✅ 정답
# google_Hilleberg Niak tent_71.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_77.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_191_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_11.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_194_1.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_206.jpg -> ✅ 정답
# google_Hilleberg Niak tent_62.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_271.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_48.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_100.jpg -> ✅ 정답
# google_Hilleberg Niak tent_75.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_4_1.jpg -> ✅ 정답
# google_Hilleberg Niak tent_52.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_113.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_71.jpg -> ✅ 정답
# google_Hilleberg Niak tent_124.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_255.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_326.jpg -> ✅ 정답
# google_Hilleberg Niak tent_80.jpg -> ✅ 정답
# naver_힐레베르그 니악 텐트_328.jpg -> ❌ 오답 (예측: 35, 정답: 11)
# google_스노우피크 도크돔 텐트_197.jpg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_18.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_15.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_134.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_71.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_83.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_78.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_64.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_58.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_7.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_16.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_63.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_174.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_26.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_156.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_13.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_27.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_142.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_52_1.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_23.jpg -> ✅ 정답
# DSC05005.jpeg -> ✅ 정답
# google_Snow Peak Dock Dome tent_8_1.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_74_1.jpg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_6.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_66_1.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_177.jpg -> ❌ 오답 (예측: 17, 정답: 12)
# DSC04984.jpeg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_2.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_154.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_93.jpg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_3.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_150.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_159.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_2.jpg -> ❌ 오답 (예측: 17, 정답: 12)
# maxresdefault (1).jpg -> ✅ 정답
# IMG_9635.jpeg -> ✅ 정답
# google_스노우피크 도크돔 텐트_194.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_138.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_115.jpg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_5.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_67.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_37_1.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_100.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_20_1.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_14.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_110.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_19.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_80.jpg -> ✅ 정답
# google_Snow Peak Dock Dome tent_14_1.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_27.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_12.jpg -> ✅ 정답
# google_스노우피크 도크돔 텐트_125.jpg -> ✅ 정답
# naver_스노우피크 도크돔 텐트_14.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_392.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_209.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_52.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_100.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_189.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_169.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_20.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_174.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_103.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_102.jpg -> ✅ 정답
# 라이더스_4.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_10.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_180.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_40.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_244.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_3.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_364.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_146.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_66.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_34.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_223.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_248.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_205.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_112.jpg -> ✅ 정답
# 1000574911926_i1_750.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_400.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_178.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_2.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_131.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_368.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_13.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_219.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_81.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_276.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_290.jpg -> ✅ 정답
# 쇼핑_라이더스_10.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_22.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_273.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_391.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_186.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_367.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_337.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_184.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_350.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_183.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_377.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_255.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_182.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_80.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_155.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_289.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_366.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_124.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_113.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_41.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_387.jpg -> ✅ 정답
# 264489206_1_1732783698_w360.webp -> ✅ 정답
# naver_DOD 라이더스 텐트_313.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_390.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_28.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_165.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_385.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_294.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_25.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_201.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_11.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_5.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_9.jpg -> ✅ 정답
# naver_DOD 라이더스 텐트_67.jpg -> ✅ 정답
# naver_스노우피크 랜드록 텐트_23.jpg -> ✅ 정답
# google_Snow Peak Land Lock tent_8.jpg -> ✅ 정답
# naver_스노우피크 랜드록 텐트_297.jpg -> ✅ 정답
# naver_스노우피크 랜드록 텐트_183.jpg -> ✅ 정답
# google_스노우피크 랜드록 텐트_141.jpg -> ✅ 정답
# google_Snow Peak Land Lock tent_34.jpg -> ✅ 정답
# google_스노우피크 랜드록 텐트_163.jpg -> ✅ 정답
# google_Snow Peak Land Lock tent_53.jpg -> ✅ 정답
# ...
# google_노르디스크 아스가르드 텐트_172.jpg -> ❌ 오답 (예측: 2, 정답: 33)
# google_노르디스크 아스가르드 텐트_129.jpg -> ✅ 정답
# naver_노르디스크 아스가르드 텐트_291.jpg -> ✅ 정답
# google_Nordisk Asgard tent_172.jpg -> ✅ 정답
# naver_노르디스크 아스가르드 텐트_293.jpg -> ✅ 정답
# google_노르디스크 아스가르드 텐트_56.jpg -> ✅ 정답
# google_폴라리스 아퀼라 텐트_40.jpg -> ✅ 정답
# naver_폴라리스 아퀼라 텐트_9_1.jpg -> ✅ 정답
# naver_폴라리스 아퀼라 텐트_35.jpg -> ✅ 정답
# google_폴라리스 아퀼라 텐트_99.jpg -> ❌ 오답 (예측: 10, 정답: 34)
# google_Polaris Aquila tent_29.jpg -> ✅ 정답
# naver_폴라리스 아퀼라 텐트_10_1.jpg -> ✅ 정답
# google_폴라리스 아퀼라 텐트_39.jpg -> ✅ 정답
# naver_폴라리스 아퀼라 텐트_26.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_24_1.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_123.jpg -> ❌ 오답 (예측: 11, 정답: 35)
# naver_힐레베르그 아틀라스 텐트_153_1.jpg -> ✅ 정답
# google_Hilleberg Atlas tent_177.jpg -> ❌ 오답 (예측: 9, 정답: 35)
# google_Hilleberg Atlas tent_144.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_95_1.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_136.jpg -> ❌ 오답 (예측: 11, 정답: 35)
# naver_힐레베르그 아틀라스 텐트_390_1.jpg -> ❌ 오답 (예측: 9, 정답: 35)
# google_Hilleberg Atlas tent_197.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_356.jpg -> ❌ 오답 (예측: 29, 정답: 35)
# naver_힐레베르그 아틀라스 텐트_367.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_257.jpg -> ✅ 정답
# google_Hilleberg Atlas tent_120.jpg -> ✅ 정답
# naver_힐레베르그 아틀라스 텐트_143.jpg -> ❌ 오답 (예측: 11, 정답: 35)
# naver_힐레베르그 아틀라스 텐트_373_1.jpg -> ❌ 오답 (예측: 9, 정답: 35)
# google_카즈미 아티카 텐트_8.jpg -> ✅ 정답
# naver_카즈미 아티카 텐트_73.jpg -> ✅ 정답
# google_Kazmi Attica tent_41.jpg -> ✅ 정답
# google_카즈미 아티카 텐트_99.jpg -> ✅ 정답
# google_Kazmi Attica tent_11.jpg -> ✅ 정답
# google_Kazmi Attica tent_57.jpg -> ❌ 오답 (예측: 25, 정답: 36)
# google_카즈미 아티카 텐트_62.jpg -> ❌ 오답 (예측: 34, 정답: 36)
# google_카즈미 아티카 텐트_26.jpg -> ❌ 오답 (예측: 25, 정답: 36)
# naver_카즈미 아티카 텐트_59.jpg -> ✅ 정답
# google_Kazmi Attica tent_72.jpg -> ✅ 정답
# google_카즈미 아티카 텐트_57.jpg -> ❌ 오답 (예측: 46, 정답: 36)
# naver_미니멀웍스 알베르게 텐트_361.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_12.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_308.jpg -> ❌ 오답 (예측: 32, 정답: 37)
# naver_미니멀웍스 알베르게 텐트_370.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_138.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_167.jpg -> ❌ 오답 (예측: 32, 정답: 37)
# naver_미니멀웍스 알베르게 텐트_235.jpg -> ❌ 오답 (예측: 30, 정답: 37)
# naver_미니멀웍스 알베르게 텐트_120.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_374.jpg -> ✅ 정답
# naver_미니멀웍스 알베르게 텐트_8.jpg -> ✅ 정답
# google_헬리녹스 알파인돔 텐트_84.jpg -> ✅ 정답
# IMG_20170408_171519.jpg -> ✅ 정답
# google_헬리녹스 알파인돔 텐트_91.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_115.jpg -> ✅ 정답
# google_헬리녹스 알파인돔 텐트_155.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_55.jpg -> ✅ 정답
# google_헬리녹스 알파인돔 텐트_191.jpg -> ❌ 오답 (예측: 12, 정답: 38)
# google_헬리녹스 알파인돔 텐트_167.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_182.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_48.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_146.jpg -> ✅ 정답
# google_Helinox Alpine Dome tent_34.jpg -> ✅ 정답
# google_헬리녹스 알파인돔 텐트_38.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_53.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_144.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_150.jpg -> ✅ 정답
# google_노르디스크 알페임 텐트_64.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_191.jpg -> ✅ 정답
# google_노르디스크 알페임 텐트_84.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_103.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_122.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_335.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_129.jpg -> ❌ 오답 (예측: 24, 정답: 39)
# google_Nordisk Alfheim tent_140.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_1.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_16.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_292.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_46.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_310.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_102.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_148.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_387.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_1.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_199.jpg -> ✅ 정답
# google_Nordisk Alfheim tent_164.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_232.jpg -> ❌ 오답 (예측: 33, 정답: 39)
# naver_노르디스크 알페임 텐트_386.jpg -> ✅ 정답
# naver_노르디스크 알페임 텐트_191.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_45.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_58.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_97.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_284.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_18.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_217.jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_130.jpg -> ❌ 오답 (예측: 12, 정답: 40)
# naver_스노우피크 어메니티돔 텐트_113.jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_176.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_78.jpg -> ✅ 정답
# bb1997773735fe9aee20a34dbd202abe_1680863547.jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_160.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_7.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_133.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_42.jpg -> ✅ 정답
# google_Snow Peak Amenity Dome tent_102.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_172.jpg -> ✅ 정답
# naver_스노우피크 어메니티돔 텐트_28.jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_142.jpg -> ✅ 정답
# maxresdefault (1).jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_107.jpg -> ❌ 오답 (예측: 15, 정답: 40)
# google_Snow Peak Amenity Dome tent_5.jpg -> ❌ 오답 (예측: 15, 정답: 40)
# naver_스노우피크 어메니티돔 텐트_171.jpg -> ❌ 오답 (예측: 17, 정답: 40)
# naver_스노우피크 어메니티돔 텐트_79.jpg -> ✅ 정답
# google_스노우피크 어메니티돔 텐트_12.jpg -> ✅ 정답
# google_제드 오토듀얼팔레스 텐트_79.jpg -> ❌ 오답 (예측: 8, 정답: 41)
# naver_제드 오토듀얼팔레스 텐트_146.jpg -> ✅ 정답
# naver_제드 오토듀얼팔레스 텐트_8.jpg -> ✅ 정답
# google_Zed Auto Dual Palace tent_23.jpg -> ❌ 오답 (예측: 48, 정답: 41)
# naver_제드 오토듀얼팔레스 텐트_20.jpg -> ✅ 정답
# naver_제드 오토듀얼팔레스 텐트_33.jpg -> ✅ 정답
# google_제드 오토듀얼팔레스 텐트_56.jpg -> ✅ 정답
# naver_제드 오토듀얼팔레스 텐트_191.jpg -> ✅ 정답
# naver_제드 오토듀얼팔레스 텐트_28.jpg -> ✅ 정답
# 14349245_1.jpg -> ✅ 정답
# naver_제드 오토듀얼팔레스 텐트_150.jpg -> ✅ 정답
# naver_DOD 와가야노 텐트_354.jpg -> ❌ 오답 (예측: 48, 정답: 42)
# naver_DOD 와가야노 텐트_345.jpg -> ❌ 오답 (예측: 8, 정답: 42)
# naver_DOD 와가야노 텐트_367.jpg -> ❌ 오답 (예측: 8, 정답: 42)
# naver_DOD 와가야노 텐트_285.jpg -> ❌ 오답 (예측: 38, 정답: 42)
# naver_DOD 와가야노 텐트_329.jpg -> ❌ 오답 (예측: 13, 정답: 42)
# naver_DOD 와가야노 텐트_155.jpg -> ❌ 오답 (예측: 48, 정답: 42)
# naver_DOD 와가야노 텐트_328.jpg -> ❌ 오답 (예측: 37, 정답: 42)
# naver_DOD 와가야노 텐트_180.jpg -> ❌ 오답 (예측: 8, 정답: 42)
# naver_DOD 와가야노 텐트_188.jpg -> ✅ 정답
# naver_DOD 와가야노 텐트_283.jpg -> ❌ 오답 (예측: 13, 정답: 42)
# naver_DOD 와가야노 텐트_138.jpg -> ✅ 정답
# naver_DOD 와가야노 텐트_336.jpg -> ❌ 오답 (예측: 8, 정답: 42)
# naver_DOD 와가야노 텐트_177.jpg -> ❌ 오답 (예측: 5, 정답: 42)
# naver_DOD 와가야노 텐트_220.jpg -> ❌ 오답 (예측: 13, 정답: 42)
# naver_DOD 와가야노 텐트_174.jpg -> ❌ 오답 (예측: 48, 정답: 42)
# google_Hilleberg Unna tent_168.jpg -> ❌ 오답 (예측: 29, 정답: 43)
# google_Hilleberg Unna tent_31.jpg -> ✅ 정답
# google_Hilleberg Unna tent_103.jpg -> ✅ 정답
# google_Hilleberg Unna tent_46.jpg -> ✅ 정답
# naver_힐레베르그 우나 텐트_1.jpg -> ❌ 오답 (예측: 11, 정답: 43)
# google_Hilleberg Unna tent_158.jpg -> ❌ 오답 (예측: 11, 정답: 43)
# naver_힐레베르그 우나 텐트_42.jpg -> ✅ 정답
# naver_힐레베르그 우나 텐트_55.jpg -> ❌ 오답 (예측: 35, 정답: 43)
# naver_힐레베르그 우나 텐트_7.jpg -> ✅ 정답
# rockycamping11_2066.jpg -> ✅ 정답
# naver_힐레베르그 우나 텐트_22.jpg -> ❌ 오답 (예측: 35, 정답: 43)
# naver_힐레베르그 우나 텐트_104.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_296.jpg -> ✅ 정답
# google_노르디스크 우트가르드 텐트_71.jpg -> ✅ 정답
# google_Nordisk Utgard tent_191.jpg -> ❌ 오답 (예측: 39, 정답: 44)
# naver_노르디스크 우트가르드 텐트_369.jpg -> ✅ 정답
# google_Nordisk Utgard tent_56.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_5.jpg -> ✅ 정답
# google_노르디스크 우트가르드 텐트_67.jpg -> ✅ 정답
# google_Nordisk Utgard tent_92.jpg -> ✅ 정답
# google_노르디스크 우트가르드 텐트_91.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_20.jpg -> ✅ 정답
# google_Nordisk Utgard tent_141.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_362.jpg -> ✅ 정답
# google_Nordisk Utgard tent_124.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_286.jpg -> ✅ 정답
# google_노르디스크 우트가르드 텐트_140.jpg -> ❌ 오답 (예측: 39, 정답: 44)
# naver_노르디스크 우트가르드 텐트_3.jpg -> ✅ 정답
# google_Nordisk Utgard tent_140.jpg -> ❌ 오답 (예측: 2, 정답: 44)
# naver_노르디스크 우트가르드 텐트_399.jpg -> ✅ 정답
# google_Nordisk Utgard tent_103.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_16.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_215.jpg -> ✅ 정답
# google_Nordisk Utgard tent_57.jpg -> ✅ 정답
# naver_노르디스크 우트가르드 텐트_82.jpg -> ✅ 정답
# google_Nordisk Utgard tent_195.jpg -> ❌ 오답 (예측: 24, 정답: 44)
# naver_콜맨 웨더마스터 텐트_166.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_255.jpg -> ❌ 오답 (예측: 1, 정답: 45)
# naver_콜맨 웨더마스터 텐트_139.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_158.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_192.jpg -> ✅ 정답
# google_콜맨 웨더마스터 텐트_94.jpg -> ❌ 오답 (예측: 36, 정답: 45)
# naver_콜맨 웨더마스터 텐트_261.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_219.jpg -> ❌ 오답 (예측: 19, 정답: 45)
# naver_콜맨 웨더마스터 텐트_212.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_291.jpg -> ✅ 정답
# google_Coleman Weathermaster tent_46.jpg -> ✅ 정답
# naver_콜맨 웨더마스터 텐트_365.jpg -> ✅ 정답
# google_Coleman Weathermaster tent_7.jpg -> ❌ 오답 (예측: 44, 정답: 45)
# google_콜맨 웨더마스터 텐트_16.jpg -> ❌ 오답 (예측: 16, 정답: 45)
# naver_콜맨 웨더마스터 텐트_173.jpg -> ✅ 정답
# google_노스피크 인디아나 텐트_64.jpg -> ✅ 정답
# naver_노스피크 인디아나 텐트_52.jpg -> ✅ 정답
# naver_노스피크 인디아나 텐트_138.jpg -> ✅ 정답
# google_North Peak Indiana tent_95.jpg -> ❌ 오답 (예측: 14, 정답: 46)
# google_노스피크 인디아나 텐트_58.jpg -> ✅ 정답
# naver_노스피크 인디아나 텐트_13.jpg -> ✅ 정답
# naver_노스피크 인디아나 텐트_47.jpg -> ✅ 정답
# google_Coleman Instant Up 3P tent_57.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_197.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_59.jpg -> ✅ 정답
# google_Coleman Instant Up 3P tent_17.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_235.jpg -> ✅ 정답
# google_Coleman Instant Up 3P tent_13.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_86.jpg -> ✅ 정답
# google_콜맨 인스턴트업 3p 텐트_70.jpg -> ✅ 정답
# google_콜맨 인스턴트업 3p 텐트_92.jpg -> ✅ 정답
# google_Coleman Instant Up 3P tent_4.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_297.jpg -> ✅ 정답
# naver_콜맨 인스턴트업 3p 텐트_47.jpg -> ✅ 정답
# google_DOD Kangaroo tent_28.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_222.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_1.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_224.jpg -> ❌ 오답 (예측: 45, 정답: 48)
# naver_DOD 캥거루 텐트_361.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_2.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_69.jpg -> ✅ 정답
# google_DOD Kangaroo tent_52.jpg -> ❌ 오답 (예측: 52, 정답: 48)
# naver_DOD 캥거루 텐트_44.jpg -> ❌ 오답 (예측: 26, 정답: 48)
# google_DOD Kangaroo tent_29.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_215.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_317.jpg -> ❌ 오답 (예측: 53, 정답: 48)
# naver_DOD 캥거루 텐트_164.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_225.jpg -> ✅ 정답
# google_DOD Kangaroo tent_60.jpg -> ✅ 정답
# naver_DOD 캥거루 텐트_126.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_127.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_251.jpg -> ✅ 정답
# google_헬리녹스 코트텐트 텐트_73.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_5.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_109.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_159.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_158.jpg -> ❌ 오답 (예측: 23, 정답: 49)
# google_Helinox Cot Tent tent_45.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_70.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_176.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_233.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_9.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_190.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_253.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_301.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_126.jpg -> ✅ 정답
# google_헬리녹스 코트텐트 텐트_27.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_133.jpg -> ✅ 정답
# google_헬리녹스 코트텐트 텐트_83.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_4.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_14.jpg -> ✅ 정답
# naver_헬리녹스 코트텐트 텐트_67.jpg -> ✅ 정답
# google_Helinox Cot Tent tent_37.jpg -> ❌ 오답 (예측: 53, 정답: 49)
# naver_몽벨 크로노스 텐트_9.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_57.jpg -> ✅ 정답
# google_몽벨 크로노스 텐트_5.jpg -> ✅ 정답
# google_Mont-bell Chronos tent_40.jpg -> ✅ 정답
# google_Mont-bell Chronos tent_13.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_65.jpg -> ✅ 정답
# google_몽벨 크로노스 텐트_95.jpg -> ❌ 오답 (예측: 31, 정답: 50)
# naver_몽벨 크로노스 텐트_62.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_130.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_93.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_167.jpg -> ✅ 정답
# google_몽벨 크로노스 텐트_2.jpg -> ✅ 정답
# google_Mont-bell Chronos tent_97.jpg -> ✅ 정답
# naver_몽벨 크로노스 텐트_88.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_23_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_1_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_85_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_3_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_29.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_266_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_80_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_37.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_320.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_51.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_396.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_72.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_76_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_61.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_67.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_214_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_39_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_299_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_318_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_346.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_136.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_247.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_11.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_276_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_195.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_362_1.jpg -> ✅ 정답
# naver_네이처하이크 클라우드업 텐트_48.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_107_1.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_220_1.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_169.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_144.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_301_1.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_155.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_26.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_77.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_214.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_53.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_153.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_27_1.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_325_1.jpg -> ✅ 정답
# naver_콜맨 투어링돔 텐트_342.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_85.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_294.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_312.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_266.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_355.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_243.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_259.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_324.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_359.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_351.jpg -> ✅ 정답
# naver_미니멀웍스 파프리카 텐트_207.jpg -> ✅ 정답
# google_헬스포츠 패스빅 텐트_185.jpg -> ✅ 정답
# 패스빅_3.jpg -> ✅ 정답
# google_헬스포츠 패스빅 텐트_35.jpg -> ✅ 정답
# google_Helsport Pasvik tent_65.jpg -> ❌ 오답 (예측: 39, 정답: 54)
# google_헬스포츠 패스빅 텐트_32.jpg -> ❌ 오답 (예측: 39, 정답: 54)
# google_헬스포츠 패스빅 텐트_199.jpg -> ❌ 오답 (예측: 20, 정답: 54)
# google_Helsport Pasvik tent_68.jpg -> ✅ 정답
# 쇼핑_패스빅_3.jpg -> ✅ 정답
# google_Helsport Pasvik tent_21.jpg -> ✅ 정답
# google_헬스포츠 패스빅 텐트_155.jpg -> ✅ 정답
# google_헬스포츠 패스빅 텐트_31_1.jpg -> ❌ 오답 (예측: 39, 정답: 54)
# google_Helsport Pasvik tent_21_1.jpg -> ✅ 정답
# google_노스피크 퍼시픽오션 텐트_6.jpg -> ❌ 오답 (예측: 6, 정답: 55)
# naver_노스피크 퍼시픽오션 텐트_66_1.jpg -> ✅ 정답
# naver_노스피크 퍼시픽오션 텐트_53.jpg -> ✅ 정답
# google_Northpeak Pacific Ocean tent_20.jpg -> ❌ 오답 (예측: 26, 정답: 55)
# naver_노스피크 퍼시픽오션 텐트_289_1.jpg -> ✅ 정답
# naver_노스피크 퍼시픽오션 텐트_52.jpg -> ✅ 정답
# naver_노스피크 퍼시픽오션 텐트_61_1.jpg -> ✅ 정답
# naver_노스피크 퍼시픽오션 텐트_258.jpg -> ✅ 정답
# naver_노스피크 퍼시픽오션 텐트_17_1.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_25.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_41.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_68.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_23.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_61.jpg -> ✅ 정답
# 테슬라-오너들의-캠핑-이야기-헬리녹스-터널텐트-evpost-23.jpg -> ❌ 오답 (예측: 23, 정답: 56)
# google_헬리녹스 필드터널 텐트_200.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_13_1.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_186.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_40.jpg -> ✅ 정답
# naver_헬리녹스 필드터널 텐트_14.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_7_1.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_18.jpg -> ✅ 정답
# google_Helinox Field Tunnel tent_4.jpg -> ✅ 정답
# google_헬리녹스 필드터널 텐트_170.jpg -> ✅ 정답
#
# ===== TEST3 데이터셋 전체 정확도: 707 / 867 = 81.55% =====
# ----- TEST3 데이터셋 클래스별 정확도 -----
# [12X] : 5 / 6 = 83.33%
# [4S 와이드] : 9 / 13 = 69.23%
# [6.3] : 12 / 15 = 80.00%
# [A5] : 8 / 9 = 88.89%
# [A7] : 11 / 12 = 91.67%
# [IE] : 5 / 9 = 55.56%
# [P1] : 12 / 13 = 92.31%
# [X5] : 4 / 8 = 50.00%
# [가마보코] : 25 / 27 = 92.59%
# [날로] : 21 / 23 = 91.30%
# [노나돔] : 20 / 23 = 86.96%
# [니악] : 10 / 21 = 47.62%
# [도크돔] : 6 / 8 = 75.00%
# [라이더스] : 10 / 11 = 90.91%
# [랜드록] : 16 / 23 = 69.57%
# [랜드브리즈] : 17 / 20 = 85.00%
# [레이사] : 23 / 25 = 92.00%
# [리빙쉘] : 21 / 28 = 75.00%
# [문라이트] : 14 / 15 = 93.33%
# [미라클패밀리] : 8 / 9 = 88.89%
# [바랑에르돔] : 15 / 16 = 93.75%
# [발할] : 10 / 11 = 90.91%
# [뱅가드] : 7 / 8 = 87.50%
# [브이타프] : 6 / 11 = 54.55%
# [비무르] : 21 / 24 = 87.50%
# [비바돔] : 4 / 8 = 50.00%
# [빌리지] : 17 / 18 = 94.44%
# [새턴 쉘터] : 10 / 14 = 71.43%
# [새턴2룸] : 8 / 13 = 61.54%
# [솔로] : 15 / 15 = 100.00%
# [쉘터G] : 9 / 11 = 81.82%
# [스텔라릿지] : 14 / 14 = 100.00%
# [아고라] : 9 / 11 = 81.82%
# [아스가르드] : 27 / 31 = 87.10%
# [아퀼라] : 7 / 8 = 87.50%
# [아틀라스] : 8 / 15 = 53.33%
# [아티카] : 7 / 11 = 63.64%
# [알베르게] : 7 / 10 = 70.00%
# [알파인돔] : 12 / 13 = 92.31%
# [알페임] : 23 / 25 = 92.00%
# [어메니티돔] : 21 / 25 = 84.00%
# [오토듀얼팔레스] : 9 / 11 = 81.82%
# [와가야노] : 2 / 15 = 13.33%
# [우나] : 7 / 12 = 58.33%
# [우트가르드] : 20 / 24 = 83.33%
# [웨더마스터] : 10 / 15 = 66.67%
# [인디아나] : 6 / 7 = 85.71%
# [인스턴트업 3p] : 12 / 12 = 100.00%
# [캥거루] : 12 / 16 = 75.00%
# [코트텐트] : 21 / 23 = 91.30%
# [크로노스] : 13 / 14 = 92.86%
# [클라우드업] : 27 / 27 = 100.00%
# [투어링돔] : 14 / 14 = 100.00%
# [파프리카] : 11 / 11 = 100.00%
# [패스빅] : 8 / 12 = 66.67%
# [퍼시픽오션] : 7 / 9 = 77.78%
# [필드터널] : 14 / 15 = 93.33%
# ======================================================
#
# ===== 전체 요약 =====
# TRAIN3 데이터셋 최종 정확도: 96.16%
# VAL3 데이터셋 최종 정확도: 83.54%
# TEST3 데이터셋 최종 정확도: 81.55%
# CSV 파일이 저장되었습니다: C:\Users\user\OneDrive\Desktop\Resnet18-real\csv\모델정확도.csv
